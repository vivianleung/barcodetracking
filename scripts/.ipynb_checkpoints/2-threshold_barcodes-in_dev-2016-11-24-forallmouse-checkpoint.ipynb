# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import os, sys

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import scipy.fftpack
import seaborn as sns

# %% [markdown]
# copied from 2-threshold_barcodes-in_dev-2016-11-24 (does work, at least for sample mouse data) to test on all mouse data

# %% [markdown]
# # USER INPUTS

# %%
"""Experiment name to prepend output files"""
EXPERIMENT = "mouse"

"""Directory path to input data 
    (filtered; output from '1-read_fastq_id_features)
"""
FILTERED_FILEPATH = "../output/filtered-mouse.csv"

"""Directory path to save output"""
OUTPUT_DIRECTORY = "../output"

"""Minimum number of reads as a baseline. Used to simplify data processing."""
MIN_READS = 100


SAMPLE_INFO_FILEPATH = "../helpers/mouse_samples.csv"

# %% [markdown]
# # PRESETS AND SCRIPT

# %%
"""Column names correspoinding to eponymous variables"""

SAMPLE = 'idx'
QTAG = 'qtag'
BARCODE = 'barcode'
READS = 'readsPF'
MCOUNTS = 'mcountsPF'
PERCENT_MCOUNTS = 'percent_%s'%MCOUNTS
GROUPBY = ['idx']

# %%
def load_data(filtered_file, sample=SAMPLE, qtag=QTAG, 
              barcode=BARCODE, mcounts=MCOUNTS, reads=READS):
    """Loads filtered lib-ID-barcode data csv to dict of samples"""
    columns = [sample, qtag, barcode, mcounts, reads]
    # loads excel file (all tabs)
    csv = pd.read_csv(filtered_file, sep=',')
    # filter out null barcodes just in case (if custom user input)
    csv = csv.loc[(csv[qtag]!='None') & (csv[barcode]!='None')]
    csv = csv[columns]
    csv[sample] = csv[sample].apply(lambda x: str(x))
    # get percent molecs per sample, store as output dict entry 
    groups = csv.groupby(sample)
    data = []
    for i, group in csv.groupby(sample):
        data.append((i,group))
    return data

# %% [markdown]
# # EXECUTE SCRIPT BELOW

# %% [markdown]
# ## EXPERIMENTAL

# %%
filtered = load_data(FILTERED_FILEPATH)
transformed = []

# %%
help(scipy.fftpack)
# Out:
# Help on package scipy.fftpack in scipy:
#
# NAME
#     scipy.fftpack
#
# FILE
#     /Users/vivianleung/anaconda/lib/python2.7/site-packages/scipy/fftpack/__init__.py
#
# DESCRIPTION
# ...
#     Discrete Fourier transforms (:mod:`scipy.fftpack`)
# ...
#
#     Fast Fourier Transforms (FFTs)
# ...
#
#     .. autosummary::
#        :toctree: generated/
#
#        fft - Fast (discrete) Fourier Transform (FFT)
#        ifft - Inverse FFT
#        fft2 - Two dimensional FFT
#        ifft2 - Two dimensional inverse FFT
#        fftn - n-dimensional FFT
#        ifftn - n-dimensional inverse FFT
#        rfft - FFT of strictly real-valued sequence
#        irfft - Inverse of rfft
#        dct - Discrete cosine transform
#        idct - Inverse discrete cosine transform
#        dst - Discrete sine transform
#        idst - Inverse discrete sine transform
#
#     Differential and pseudo-differential operators
# ...
#
#     .. autosummary::
#        :toctree: generated/
#
# ...

# %%
def transform_vals(y):
    x = range(1,len(y)+1)      
    w = scipy.fftpack.rfft(y)
    f = scipy.fftpack.rfftfreq(len(y), x[1]-x[0])
    spectrum = w**2

    cutoff_val = spectrum.max()/5
    cutoff_idx = spectrum < cutoff_val
    w2 = w.copy()
    w2[cutoff_idx] = 0
    y2 = scipy.fftpack.irfft(w2)

    # find threshold as arg min of 
    # derivative of inverse transformed data
    y2d  =y2[1:]-y2[:-1]
    t = np.argmin(y2d[:-1])+1
    
    return y2, t

# %%
N = 1000
transformed_arr = []
t_cols = ['idx','sample_num','t','raw_y','trans_y']
for idx, raw_df in filtered:
    vals = {'idx':idx}
    raw_y = raw_df.mcountsPF.values
    vals['raw_y'] = raw_y
    if sum(raw_y) > N:
        vals['trans_y'], vals['t'] = transform_vals(raw_y)
        vals['sample_num'] = int(idx.split("V")[1])
        transformed_arr.append([vals[c] for c in t_cols ])
    else:
        print idx

transformed = pd.DataFrame(transformed_arr, columns=t_cols)
transformed = transformed.set_index('sample_num').sort_index()
# Out:
# CS-V12
# CS-V28
# CS-V38
# V12
# V84
# neg

# %%
# read and wrangle samples info list
samples = pd.read_csv(SAMPLE_INFO_FILEPATH).dropna(how="all")
samples.drop(['extracted','log_cfu','concentration'], axis=1, inplace=True)
samples.loc[:,'week'] = samples['week'].apply(lambda x: int(x.split("wk")[0]))
samples.set_index("sample_num",inplace=True)

# %%
def group_series(group):
    new_cols = ['trans_y','raw_y','t','rep']    
    series = pd.Series()
    for k in new_cols:
        series[k] = group[k].values
    return series

groupby = ['mouse_geno','week','tb_strain','tissue']
merged = pd.merge(transformed, samples, 
                  how='left', left_index=True, right_index=True)
merged.dropna(how='any',inplace=True)
pivoted = merged.groupby(groupby, as_index=False
              ).apply(group_series).reset_index()
pivoted['week'] = pivoted['week'].astype(int)

# %%
sns.set_style('white')
# colors = ['blue','red', 'green','purple','orange','pink', 'yellow']
colors = [   
    '#2C5EBF', # blue
    '#FF1313', # red
    '#F7B02A', # yellow
    '#02B72A', # green
    '#009E9E', # turquoise
    '#1D1AA9', # dark blue
    '#FF6D13', # orange
    '#8E008E'  # purple
]
mean_color = 'grey'

# %% [markdown]
# # PLOT INDIVIDUALS

# %%
def plot_transformed_sample(trans_y, raw_y, t,sample_info):
    # define y vals
    raw_yplot = np.log10(raw_y)
    trans_yplot = np.log10(trans_y)
    trans_yplot[np.isnan(trans_yplot)==True] = 0
    
    # define threshold y vals
    tspan = np.log10([np.min(raw_y+trans_y), np.max(raw_y+trans_y)])
    tspan[np.isnan(tspan)] = 0
    t_x = [t,t]
    
    # define x vals
    raw_xplot = range(len(raw_y))
    trans_xplot = range(len(trans_yplot))
    
    # make label names
    sample_name = " ".join([str(s) for s in sample_info])
    num_barcodes = "%d barcode%s"%(t,"" if t==1 else "s")
    xlabel = 'barcode, rank-ordered'
    ylabel = 'log10 abundance (# molecules)'
    title = "%s: %s"%(sample_name, num_barcodes)
    
    # plot
    f1, ax1 = plt.subplots(1)
    ax1.plot(raw_xplot,raw_yplot, 
             label='raw values', lw=3, c="red")
    ax1.plot(trans_xplot,trans_yplot, 
             label='inversed FFT', lw=2, alpha=0.8)
    ax1.plot(t_x,tspan, 
             lw=2, c='green',label="threshold: %s"%num_barcodes)
    
    # axis-wide formatting
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)
    ax1.set_ylim(top=tspan[1],bottom=0)
    ax1.set_xlim(left=-10,right=800)
    ax1.set_title(title)
    ax1.legend()
    
    return f1, ax1

# %% [markdown]
# # PLOT INDIVIDUAL

# %%
"""PLOT INDIVIDUAL SAMPLES"""
for sample_num, row in merged.iterrows():
    raw_y = row['raw_y']
    trans_y = row['trans_y']
    t = row.t
    row_info = [s for s in row[groupby+['rep']]]
    row_info[1] = str(int(row_info[1]))+"wks"
    row_info[4] = str(int(row_info[4]))
    f, ax = plot_transformed_sample(trans_y, raw_y, t,row_info)
    f.set_size_inches(8,5)
    save_file = "-".join(row_info)
    f.savefig("%s/figs-svg-indiv-fixedx-all/%s.svg"%(OUTPUT_DIRECTORY,save_file))
    f.savefig("%s/figs-png-indiv-fixedx-all/%s.png"%(OUTPUT_DIRECTORY,save_file))

# %% [markdown]
# # PLOT BY GROUPS

# %% [markdown]
# ### PLOT BY ALL (Mouse, Weeks, TB, Tissue)

# %%
"""A)  PLOT PER GROUP W groupby_all"""
for _, row in pivoted.iterrows():
    trans_y, raw_y, t = row[['trans_y','raw_y','t']].values
    f1, ax1 = plt.subplots(1)
    row_info = [s for s in row[groupby]]
    row_info[1] = str(int(row_info[1]))+"wks"
    title = " ".join(row_info)
    y = raw_y

    yplot = [np.log10(yi) for yi in y]
    xplot = [range(len(yi)) for yi in y]
    
    alpha = 0.7
    span_vals = np.concatenate(raw_y)+np.concatenate(trans_y)
    tspan = np.log10([np.min(span_vals), np.max(span_vals)*1.1])
    tspan[np.isnan(tspan)] = 0
    avg_t = np.mean(t)
    
    ax1.plot([avg_t,avg_t],tspan, 
             lw=3, c=mean_color, alpha=1, label='mean threshold: %i'%avg_t)
    
    c = 0
    for tx, ty, ti in zip(xplot, yplot, t):
        color = colors[c%len(colors)]
        ax1.plot(tx, ty,lw=2, c=color, alpha=0.4, label="mouse %i: %i"%((c+1),ti))
        ax1.plot([ti,ti],tspan,lw=2, c=color, alpha=1, ls='--')
        c += 1
    xlabel = 'barcode, rank-ordered'
    ylabel = 'log10 abundance (# molecules)'

    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)
    ax1.set_ylim(top=tspan[1],bottom=0)
    ax1.set_xlim(left=-10,right=np.max([len(xi) for xi in xplot]))
    ax1.set_title(title)
    ax1.legend()
    old_yticklabels = [yt.get_text() for yt in ax1.get_yaxis().get_ticklabels()]
    new_yticklabels = [str(10**int(yt)) if len(yt)>0 else "" for yt in old_yticklabels]
    tspan[1]
    yticks = np.array([10**i for i in range(len(str(int(10**tspan[1]))))])
    ytickpos = np.log10(yticks)
    yticklabels = [str(yt) for yt in yticks]
    
    ax1.set_yticks(ytickpos)
    ax1.set_yticklabels(yticklabels)
    ax1.tick_params(length=5, axis='both', right='off',top='off')
    
#     row_info = [s for s in row[groupby+['rep']]]
#     row_info[1] = str(int(row_info[1]))+"wks"
#     row_info[4] = str(int(row_info[4]))

# #     break
    f1.savefig("%s/figs-svg-group-reps-all/%s.svg"%(OUTPUT_DIRECTORY,"-".join(row_info)))
    f1.savefig("%s/figs-png-group-reps-all/%s.png"%(OUTPUT_DIRECTORY,"-".join(row_info)))

# %% [markdown]
# ### PLOT TISSUES TOGETHER

# %%
groupby_tissue = ['mouse_geno','week','tb_strain']

# %%
"""B)  PLOT PER GROUP comparing tissues"""
groups = pivoted.groupby(groupby_tissue)
y_param = 'raw_y'
for gname, group in groups:
    c = 0
    f1, ax1 = plt.subplots(1)
    row_info = [s for s in gname]
    row_info[1] = str(int(row_info[1]))+'wks'
    title = " ".join(row_info)
    tspan = np.log10([1,
             np.max([ [np.max(r) for r in row] 
                for row in group[y_param].values])[0] 
            ])
    
    xlim_right = np.max([ np.max([len(r) for r in row]) 
                         for row in group[y_param].values] )
        
    c = 0
    avg_ts = []
    for _, row in group.iterrows():
        tissue = row.tissue
        color = colors[c%len(colors)]
        y = row[y_param]
        yplot = [np.log10(yi) for yi in y]
        xplot = [range(len(yi)) for yi in y]
        
        avg_t = np.mean(row['t'])
        for tx, ty in zip(xplot, yplot):
            ax1.plot(tx, ty,lw=1, c=color, alpha=0.5)
        label = '%s (n=%i): %i barcodes'%(row.tissue,len(y),avg_t)
        avg_ts.append((avg_t,color,label))
        c += 1

    for avg_t, color, label in avg_ts:
        ax1.plot([avg_t,avg_t],tspan, 
         lw=2, c=color, alpha=1, label=label)

    ax1.set_xlabel('barcode, rank-ordered')
    ax1.set_ylabel('log10 abundance (# molecules)')
    ax1.set_ylim(tspan)
    ax1.set_xlim(-10,xlim_right)
    ax1.set_title(title)
    ax1.legend()
    
    yticks = np.array([10**i for i in range(len(str(int(10**tspan[1]))))])
    ytickpos = np.log10(yticks)
    yticklabels = [str(yt) for yt in yticks]
    
    ax1.set_yticks(ytickpos)
    ax1.set_yticklabels(yticklabels)
    ax1.tick_params(length=5, axis='both', right='off',top='off')
    ax1.set_xlim(right=1000)
    
    save_file = "-".join(row_info)
    f1.savefig("%s/figs-svg-group-tissues-all/%s.svg"%(OUTPUT_DIRECTORY,save_file))
    f1.savefig("%s/figs-png-group-tissues-all/%s.png"%(OUTPUT_DIRECTORY,save_file))

# %% [markdown]
# # WRANGLE DATA FOR OUTPUT

# %%
melted = pd.melt(merged[groupby_tissue+['tissue','t','rep']], groupby_tissue+['tissue','rep']).drop('variable',axis=1)
melted[['week','rep']] = melted[['week','rep']].astype(int)

# %%
def assign_arb_num(group):
    output = group.sort_values(by='rep')
    output['arb_rep'] = range(1,len(group)+1)
    output.reset_index(inplace=True,drop=True)
#     output.set_index('arb_rep',inplace=True)
    return output
melted['arb_rep'] = 0

melted.sort_values(by=groupby_tissue+['tissue','rep'], inplace=True)
melted = melted.groupby(groupby_tissue+['tissue'], as_index=False).apply(assign_arb_num)
melted.reset_index(drop=True, inplace=True)

# %%
pivoted.to_csv('%s/pivoted-%s.csv'%(OUTPUT_DIRECTORY,EXPERIMENT),index=False)
melted.to_csv('%s/thresholded-%s.csv'%(OUTPUT_DIRECTORY,EXPERIMENT),index=False)

# %%
melt_pivot = melted.pivot_table( index=groupby_tissue+['tissue'],values='value',columns='rep', fill_value=-1)
melt_pivot[melt_pivot.columns] = melt_pivot[melt_pivot.columns].astype(int)
melt_pivot.replace(to_replace=-1,value="",inplace=True)
melt_pivot.reset_index().to_csv('%s/thresholded-by_rep-%s.csv'%(OUTPUT_DIRECTORY, EXPERIMENT),index=False)

# %%
melt_pivot_arb = melted.pivot_table( index=groupby_tissue+['tissue'],values='value',columns='arb_rep', fill_value="").reset_index()
melt_pivot_arb.to_csv('%s/thresholded-arbitrary_rep_no-%s.csv'%(OUTPUT_DIRECTORY,EXPERIMENT),index=False)

# %% [markdown]
# # GRAPHS IN PROGRESS

# %% [raw]
# # sns.swarmplot(x="measurement", y="value", hue="species", data=iris)
# f, ax = plt.subplots(1)
# sns.swarmplot(x='colname', y="value",hue="tissue",data=melted_select, ax=ax,
#              s=10)
# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

# %% [raw]
# tissues = np.unique(pivoted.tissue.values)
# color_dict = dict( [(tissue,colors[i%len(colors)]) for tissue,i in zip(tissues,range(len(tissues)))] )
# print color_dict
# fs, axs = plt.subplots(1)
# add_label = dict([ (tissue,True) for tissue in tissues ])
# xticks = []
# xticklabels = []
# for i, row in pivoted.iterrows():
#     y = row['t']
#     x = [i+1 for _ in y]
#     color = color_dict[row.tissue]
# #     label =  if add_label else None
#     label = row.tissue if add_label[row.tissue] else None
#     add_label[row.tissue] = False
#     axs.scatter(x,y,label=label, s=50,
#                color=color, lw=3, alpha = 0.5)
# #     tick = [str(row['week'])+'wk', row['tb_strain']  ]
# #     xticklabels.append(" ".join(tick))
# #     xticks.append(i+1)
# axs.legend()
# # axs.set_xticks(xticks)
# # axs.set_xticklabels(xticklabels, rotation=45, horizontalalignment='right')
# axs.tick_params(length=5, axis='both', right='off',top='off')

# %% [markdown]
# ### APPENDIX

# %% [raw]
# # for older versions/ formats
# SAMPLE = 'idx'
# QTAG = 'qtag'
# BARCODE = 'gtag'
# READS = 'reads'
# MCOUNTS = 'molecs'
# PERCENT_MCOUNTS = 'percent_%s'%MCOUNTS
# GROUPBY = ['idx']

# %%
 """DFT code is from http://stackoverflow.com/questions/20618804/"""

""" [1] w = scipy.fftpack.rfft(y)

    Discrete Fourier transform of a real sequence
    rfft(x, n=None, axis=-1, overwrite_x=False); w= transformed y

    returns 
    [y(0),Re(y(1)),Im(y(1)),...,Re(y(n/2))]              if n is even
          [y(0),Re(y(1)),Im(y(1)),...,Re(y(n/2)),Im(y(n/2))]   if n is odd
     y(j) = sum[k=0..n-1] x[k] * exp(-sqrt(-1)*j*k*2*pi/n)
          j = 0..n-1
""" 
"""[2] f = scipy.fftpack.rfftfreq(N, x[1]-x[0])
        
    DFT sample frequencies (for usage with rfft, irfft)
    rfftfreq(n, d=1.0)
    n = window (usually size(w))
    d = sample space
    returns
    f = [0,1,1,2,2,...,n/2-1,n/2-1,n/2]/(d*n)   if n is even
      f = [0,1,1,2,2,...,n/2-1,n/2-1,n/2,n/2]/(d*n)   if n is odd

      where 
      The array of length `n`, containing the sample frequencies
    """



"""[2] y2 = scipy.fftpack.irfft(w2)

    irfft(x, n=None, axis=-1, overwrite_x=False)

    Return inverse discrete Fourier transform of real sequence x.

    The contents of `x` are interpreted as the output of the `rfft`
    function

    x : array_like
        Transformed data to invert.
    n : int, optional
        Length of the inverse Fourier transform.
        If n < x.shape[axis], x is truncated.
        If n > x.shape[axis], x is zero-padded.
        The default results in n = x.shape[axis].

        fn is similar to Inverse Fournier Transformation; 
        recovers function from FT: "statement is like if we know all
        frequency and phase information about a wave, then we may 
        reconstruct the original wave precisely". aka Fournier 
        integral theorem.
"""
# Out:
# '[2] y2 = scipy.fftpack.irfft(w2)\n\n   irfft(x, n=None, axis=-1, overwrite_x=False)\n\n   Return inverse discrete Fourier transform of real sequence x.\n\n   The contents of `x` are interpreted as the output of the `rfft`\n   function\n\n   x : array_like\n       Transformed data to invert.\n   n : int, optional\n       Length of the inverse Fourier transform.\n       If n < x.shape[axis], x is truncated.\n       If n > x.shape[axis], x is zero-padded.\n       The default results in n = x.shape[axis].\n\n       fn is similar to Inverse Fournier Transformation; \n       recovers function from FT: "statement is like if we know all\n       frequency and phase information about a wave, then we may \n       reconstruct the original wave precisely". aka Fournier \n       integral theorem.\n'

# %% [raw]
# #####  Color Palette by Paletton.com
# #####  Palette URL: http://paletton.com/#uid=c0V3J2T001kqyv1rslVt4sGj9yc7pJZkriCYn2--p5B3tKFaxyH-kvHuqoZx4sevOvZqry1nyktDKF8czOl5AGTvUR+UE6
#
# *** Primary color: Yellow
#
#    shade 0 = #F7B02A = rgb(247,176, 42) = rgba(247,176, 42,1) = rgb0(0.969,0.69,0.165)
#    shade 1 = #AF7B19 = rgb(175,123, 25) = rgba(175,123, 25,1) = rgb0(0.686,0.482,0.098)
#    shade 2 = #E59D15 = rgb(229,157, 21) = rgba(229,157, 21,1) = rgb0(0.898,0.616,0.082)
#    shade 3 = #FFCA66 = rgb(255,202,102) = rgba(255,202,102,1) = rgb0(1,0.792,0.4)
#    shade 4 = #FFEBC4 = rgb(255,235,196) = rgba(255,235,196,1) = rgb0(1,0.922,0.769)
#
# *** Secondary color (1): Green
#
#    shade 0 = #02B72A = rgb(  2,183, 42) = rgba(  2,183, 42,1) = rgb0(0.008,0.718,0.165)
#    shade 1 = #2BC34C = rgb( 43,195, 76) = rgba( 43,195, 76,1) = rgb0(0.169,0.765,0.298)
#    shade 2 = #17C03C = rgb( 23,192, 60) = rgba( 23,192, 60,1) = rgb0(0.09,0.753,0.235)
#    shade 3 = #009F23 = rgb(  0,159, 35) = rgba(  0,159, 35,1) = rgb0(0,0.624,0.137)
#    shade 4 = #008E1F = rgb(  0,142, 31) = rgba(  0,142, 31,1) = rgb0(0,0.557,0.122)
#
# *** Secondary color (2): Red
#
#    shade 0 = #FF1313 = rgb(255, 19, 19) = rgba(255, 19, 19,1) = rgb0(1,0.075,0.075)
#    shade 1 = #FFBEBE = rgb(255,190,190) = rgba(255,190,190,1) = rgb0(1,0.745,0.745)
#    shade 2 = #FF5757 = rgb(255, 87, 87) = rgba(255, 87, 87,1) = rgb0(1,0.341,0.341)
#    shade 3 = #FF0000 = rgb(255,  0,  0) = rgba(255,  0,  0,1) = rgb0(1,0,0)
#    shade 4 = #FF0000 = rgb(255,  0,  0) = rgba(255,  0,  0,1) = rgb0(1,0,0)
#
# *** Complement color: Blue
#
#    shade 0 = #2C5EBF = rgb( 44, 94,191) = rgba( 44, 94,191,1) = rgb0(0.173,0.369,0.749)
#    shade 1 = #4068B6 = rgb( 64,104,182) = rgba( 64,104,182,1) = rgb0(0.251,0.408,0.714)
#    shade 2 = #3763BA = rgb( 55, 99,186) = rgba( 55, 99,186,1) = rgb0(0.216,0.388,0.729)
#    shade 3 = #2058C5 = rgb( 32, 88,197) = rgba( 32, 88,197,1) = rgb0(0.125,0.345,0.773)
#    shade 4 = #1351CB = rgb( 19, 81,203) = rgba( 19, 81,203,1) = rgb0(0.075,0.318,0.796)
#
#
# #####  Generated by Paletton.com (c) 2002-2014
#
#
#
# #####  Color Palette by Paletton.com
# #####  Palette URL: http://paletton.com/#uid=c3i4W400n1kZ8xrVinFXUsvQiVFoEJEkF9rnxYsqBerUIIqOLWqakvHuqoZx4sevOvZqry1nyktDKF8czOl5AGTvUR+UE6
#
#
# *** Primary color: Turquoise
#
#    shade 0 = #009E9E = rgb(  0,158,158) = rgba(  0,158,158,1) = rgb0(0,0.62,0.62)
#    shade 1 = #007171 = rgb(  0,113,113) = rgba(  0,113,113,1) = rgb0(0,0.443,0.443)
#    shade 2 = #008888 = rgb(  0,136,136) = rgba(  0,136,136,1) = rgb0(0,0.533,0.533)
#    shade 3 = #00EEEE = rgb(  0,238,238) = rgba(  0,238,238,1) = rgb0(0,0.933,0.933)
#    shade 4 = #2EC8C8 = rgb( 46,200,200) = rgba( 46,200,200,1) = rgb0(0.18,0.784,0.784)
#
# *** Secondary color (1): Dark Blue
#
#    shade 0 = #1D1AA9 = rgb( 29, 26,169) = rgba( 29, 26,169,1) = rgb0(0.114,0.102,0.663)
#    shade 1 = #3F3CB5 = rgb( 63, 60,181) = rgba( 63, 60,181,1) = rgb0(0.247,0.235,0.71)
#    shade 2 = #2E2CB1 = rgb( 46, 44,177) = rgba( 46, 44,177,1) = rgb0(0.18,0.173,0.694)
#    shade 3 = #181693 = rgb( 24, 22,147) = rgba( 24, 22,147,1) = rgb0(0.094,0.086,0.576)
#    shade 4 = #141283 = rgb( 20, 18,131) = rgba( 20, 18,131,1) = rgb0(0.078,0.071,0.514)
#
# *** Secondary color (2): Orange
#
#    shade 0 = #FF6D13 = rgb(255,109, 19) = rgba(255,109, 19,1) = rgb0(1,0.427,0.075)
#    shade 1 = #FFD7BE = rgb(255,215,190) = rgba(255,215,190,1) = rgb0(1,0.843,0.745)
#    shade 2 = #FF9757 = rgb(255,151, 87) = rgba(255,151, 87,1) = rgb0(1,0.592,0.341)
#    shade 3 = #FF6200 = rgb(255, 98,  0) = rgba(255, 98,  0,1) = rgb0(1,0.384,0)
#    shade 4 = #FF6200 = rgb(255, 98,  0) = rgba(255, 98,  0,1) = rgb0(1,0.384,0)
#
# *** Complement color: Purple
#
#    shade 0 = #8E008E = rgb(142,  0,142) = rgba(142,  0,142,1) = rgb0(0.557,0,0.557)
#    shade 1 = #930093 = rgb(147,  0,147) = rgba(147,  0,147,1) = rgb0(0.576,0,0.576)
#    shade 2 = #910091 = rgb(145,  0,145) = rgba(145,  0,145,1) = rgb0(0.569,0,0.569)
#    shade 3 = #8B008B = rgb(139,  0,139) = rgba(139,  0,139,1) = rgb0(0.545,0,0.545)
#    shade 4 = #880088 = rgb(136,  0,136) = rgba(136,  0,136,1) = rgb0(0.533,0,0.533)
#
#
# #####  Generated by Paletton.com (c) 2002-2014
