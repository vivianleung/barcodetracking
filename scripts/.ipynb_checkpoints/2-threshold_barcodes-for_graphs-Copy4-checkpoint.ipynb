# %%
# %matplotlib inline


import pandas as pd
import numpy as np
import regex
import os, sys
import matplotlib.pyplot as plt

# %% [markdown]
# # USER INPUTS

# %%
"""Experiment name to prepend output files"""
EXPERIMENT = "ratio_graphing-2"

"""Directory path to input data 
    (filtered; output from '1-read_fastq_id_features)
"""
FILTERED_FILEPATH = "../output/filtered-ratios.csv"
# FILTERED_FILEPATH = "../output/filtered-18014.csv"
# FILTERED_FILEPATH = '../../../2016-09-19-validation_graphs_redoes/data/filtered-ratios.csv'
"""Directory path to save output"""
OUTPUT_DIRECTORY = "../output"

"""Minimum number of reads as a baseline. Used to simplify data processing."""
MIN_READS = 100

# %% [markdown]
# # PRESETS AND SCRIPT

# %%
"""
# NEED TO FIGURE HOW TO RELOAD DEPENDENT FUNCTIONS
UPON VALUE CHANGES
Column names correspoinding to eponymous variables"""

SAMPLE = 'idx'
QTAG = 'qtag'
BARCODE = 'barcode'
READS = 'readsPF'
MCOUNTS = 'mcountsPF'
PERCENT_MCOUNTS = 'percent_%s'%MCOUNTS
GROUPBY = ['idx']# for older versions/ formats

# %%
def check_inputs():
    
    # modules
    assert pd
    assert np
    assert regex
    assert os
    assert sys
    
    # user experiment inputs 
    assert EXPERIMENT
    assert FILTERED_FILEPATH
    assert OUTPUT_DIRECTORY
    assert MIN_READS
    
    # user columns
    assert SAMPLE
    assert QTAG
    assert BARCODE
    assert READS
    assert MCOUNTS
    assert PERCENT_MCOUNTS
    assert GROUPBY

# %%
# 2016-11-04 updated to include filter delete bool feature
"""calculate_percent_molecs
    calculates percent of mcounts of barcodes.
    df: pd.DataFrame() 
    mcounts: str, optional, col to calculate percents, default MCOUNTS
    percent_mcounts: str, col to assign values to, default PERCENT_MCOUNTS
    filters: list, np.array, dict, columns and bool values to filter values
    
    Returns: 
        df with updated percent_mcounts values
"""
def calculate_percent_molecs(df, mcounts=MCOUNTS, percent_mcounts=PERCENT_MCOUNTS, filters=[]):
    """Updates percent molec counters for sample"""
    
    df.loc[:,percent_mcounts] = 0.
    if len(filters) > 0:
        var, val = filters[0]
        cond = (df[var]==val)
        i = 1
        while i < len(filters):
            var, val = filters[i]
            cond = cond & (df[var]==val)
            i+=1
    else:
        cond = ()
    total = df.loc[cond, mcounts].values.sum() / 100.
    df.loc[cond,percent_mcounts] = df.apply(lambda x: x[mcounts]/total, axis=1)
    df.sort_values(by=[percent_mcounts,mcounts, BARCODE], 
                   ascending=[0,0,1], inplace=True)
    return df

# %%
def load_data(filtered_file, sample=SAMPLE, qtag=QTAG, 
              barcode=BARCODE, mcounts=MCOUNTS, reads=READS):
    """Loads filtered lib-ID-barcode data csv to dict of samples"""
    columns = [sample, qtag, barcode, mcounts, reads]
    # loads excel file (all tabs)
    
    csv = pd.read_csv(filtered_file)
    # filter out null barcodes just in case (if custom user input)
    csv = csv.loc[(csv[qtag]!='None') & (csv[barcode]!='None')]
    csv = csv[columns]
    csv[sample] = csv[sample].apply(lambda x: str(x))
    # get percent molecs per sample, store as output dict entry 
    groups = csv.groupby(sample)
    data = []
    for i, group in csv.groupby(sample):
        data.append((i,calculate_percent_molecs(group)))
    return data

# %%
def check_data(d, sample=SAMPLE, mcounts=MCOUNTS, reads=READS):
    """Check data for proper format, input values, and 
    converts into list-like object if necessary

    d(list, np.array ,dict, or pd.DataFrame): input data
    
    Returns: data set as a list-like object, wherein
        each item is a pair containing sample name (str) and 
        sample data (pd.DataFrame), in that order.
    """
    data_arr = []
    # wrangle data to list of list-like pairs, as "[idx, df]"
    if type(d) in [np.array, list] :
        data_arr = d
    elif type(d) == dict:
        data_arr = d.items()
    elif type(d) == pd.DataFrame :
        data_arr = [(s,df) for s,df in d.groupby(sample)]
    else:
        print "Input data is not in correct format. Please provide \
        list-like, dict, or pd.DataFrame object."
    
    # check input has correct values
    try:
        for a in data_arr:
            assert len(a) == 2, "incorrect item length"
            s, df = a
            assert type(s) == str, 'sample name is not string type'
            assert type(df) == pd.DataFrame, "incorrect value type: must be pd.DataFrame"
            assert sample in df.columns, "%s not in dataframe"%sample
            assert mcounts in df.columns, "%s not in dataframe"%mcounts
            assert reads in df.columns, "%s not in dataframe"%reads
    # if no 
    except IndexError as e:
        print "Item number of values is not 2.\n"
        print "IndexError. ",e.message
        print a
    except ValueError as e:
        print "Sample name could not be converted to float: %s\n"% type(item[i])
        print "ValueError. ",e.message
        print a
    except AssertionError as e:
        print "Assertion failed:"
        print e.message
        print a
    
    return data_arr

# %%
"""OLD THRESHOLD"""

def threshold(group, reps_remaining, thresh_mcounts,threshold_log,
             mcounts=MCOUNTS):
    """Thresholds barcodes of a given sample

        group(pd.DataFrame): df containing library-ID-barcodes, 
            mcountsPF and percent_mcountsPF
        reps_remaining(int): reps remaining from max number 
            input from user 
        thresh_val(float or int): initial threshold value (percent_mcountPF)
            provided from previous recursion or user input
        thresh_i(int): initial position of threshold value in 
            percent_mcountsPF list, ranging 0,len(group)

        Returns: 
            None, if thresholding fails;
            passed(pd.DataFrame), if thresholding successful; or
            self, otherwise, with updated threshold values and 
                group df.
    """
#     print "\nSTART", len(group)
    # max out reps
    if reps_remaining <= 0:
        print 'Maxed out reps. Skipping sample.'
    # no barcodes passed threshold 
    elif len(group) == 0:
        print "No barcodes passed threshold. Skipping sample."
    else:
        # calculate new threshold 
        group.sort_values(by=mcounts, ascending=False, inplace=True)
        mcount_vals = group.loc[(group['passed']==True)|(group['is_padding']==True)][mcounts].values
#         mcount_vals = thresh_group[mcounts].values
#         mcount_vals = mcount_vals + [1] if thresh_mcounts < 0 or len(thresh_group) <= 3 else mcount_vals
#         print "G", group
#         print "THRG", thresh_group
#         print"MCV",  mcount_vals
#         print "else", reps_remaining, len(group), len(mcount_vals)
        new_thresh_mcounts = calculate_threshold(mcount_vals)
#         print "after", reps_remaining, len(group), thresh_mcounts, new_thresh_mcounts
        
        threshold_log.append(len(group.loc[group[mcounts]>=new_thresh_mcounts]))
        print '\n',reps_remaining, len(group)
        print 'old', thresh_mcounts
        print group.loc[(group[mcounts]>=thresh_mcounts)&(group[mcounts]>1)][['qtag','barcode','mcountsPF','passed','is_padding']]
        print 'new', new_thresh_mcounts
        print group.loc[group[mcounts]>=new_thresh_mcounts][['qtag','barcode','mcountsPF','passed','is_padding']]
#         print len(thresh_group.loc[thresh_group[mcounts]>new_thresh_mcounts])
        
#         print len(group), len(thresh_group)
        # if reached steady state
        if new_thresh_mcounts == thresh_mcounts:
#             re_thresholded_v = calculate_threshold(group.loc[group['passed']==True][mcounts].values)
#             print thresh_mcounts, re_thresholded_v
#             passed = eliminate_oneoffs(group, re_thresholded_v, pad=False)
#             passed = eliminate_oneoffs(group, new_thresh_mcounts, pad=False)
#             print len(group.loc[group['passed']==True]), len(passed.loc[passed['passed']==True])
            group['passed'] = group.apply(lambda x:
                            True if x['passed']==True and
                            x['is_padding']==False and
                            x[mcounts]>=new_thresh_mcounts else False, axis=1)
            passed_val = group.loc[group['passed']==True,mcounts].min()
            threshold_log.append(len(group.loc[group[mcounts]>=passed_val]))

            print 'final'
            print group.loc[group['passed']==True][['qtag','barcode','mcountsPF','passed','is_padding']]
#             group.loc[(group['passed']==True)
#                               &(group['is_padding']==False)
#                               &(group[mcounts]>=thresh_mcounts)]
            
            group = calculate_percent_molecs(group,filters=[['passed',True],['is_padding',False]])
#             passed = calculate_percent_molecs(group, 
#                         filters=[['passed',True],['is_padding',False]])
            group.reset_index(inplace=True,drop=True)
            print "FINAL", len(group.loc[group['passed']==True])
            sys.stdout.write('Thresholded.\n')
            return group, threshold_log
        # recursively clean and re-threshold
        else:
#             print reps_remaining
#             print len(group), thresh_mcounts, new_thresh_mcounts
            # clean up group by eliminating one-offs
            cleaned = eliminate_oneoffs(group,new_thresh_mcounts)
            cleaned.reset_index(inplace=True,drop=True)
#             print reps_remaining, len(cleaned.loc[cleaned['passed']==True])
            # recurse with cleaned df and new threshold values
            return threshold(cleaned, reps_remaining-1, new_thresh_mcounts, threshold_log,
                             mcounts=mcounts)
        
    # if thresholding failed, return None
    sys.stdout.write('Skipped.\n')
    return pd.DataFrame()

# %%
# STEP 2: CALCULATE THRESHOLD VALUE via. CONCAVITY


def calculate_threshold(y, by='passed', mcounts=MCOUNTS):
    """Calculates threshold of series with modified concavity approach

        y(np.array or list): list or list-like object of 
            values as floats or ints

        Returns index of inflection point in array, 
            i.e. threshold position.
    """
    def rolling_window(arr):
        """Constructs list of overlapping subarray ranges of size 2"""
        shape = arr.shape[:-1] + (arr.shape[-1]-1, 2)
        strides = arr.strides + (arr.strides[-1],)
        windows = np.lib.stride_tricks.as_strided(arr, 
                              shape=shape, strides=strides)
        return windows
    def first_d_gen(windows):
        """Generates first derivative of windows as relative difference"""
        for w in windows:
            # amended 2016-10-12: normalize by y midpoint instead of second point to 
            # better represent the count magnitude of segment
            yield float(w[1]-w[0])/(w[0]+w[1])*2
    def second_d_gen(windows):
        """Generates second derivative of windows"""
        for w in windows:
            yield w[1]-w[0]       
            
    if type(y) in [np.ndarray, list]:
        x_temp = np.array([])
        y_temp = np.array(y)
    else:
        y = pd.DataFrame(y)
        sortby, cond = [mcounts], (y[mcounts]>0)
        if by in y.columns:
            sortby, cond = ['passed']+sortby, cond&(y['passed']==True) 
        passed = y.loc[cond].sort_values(by=sortby,ascending=False)[mcounts]
        x_temp = passed.index.values
        y_temp = passed.values
    
    
    y_temp = np.sort(np.array(y_temp))[::-1]
    # left and right padding to cover all array vals in derivations
    suffix = [] if len(y_temp) > 2 else [1]
#     suffix=[]
#     suffix = [] if len(y_temp) > 1 else [y_temp[0]]
#     suffix = [y_temp[len(y_temp)-1]/(y_temp[0]+y_temp[1])*2]
#     if len(y_temp) < 2:
#         suffix = [y_temp[len(y_temp)-1]/2]
#     else:
#         suffix =  [y_temp[len(y_temp)-1] -
#                    (y_temp[len(y_temp)-2]-y_temp[len(y_temp)-1])]
    
    yarray = np.concatenate([ [y_temp[0]], y_temp, suffix])
    # calculates first derivative
    first_windows = rolling_window(yarray)
    first_derivs = np.fromiter(first_d_gen(first_windows), np.float
                               , count=len(first_windows))
    # calculates second derivative
    second_windows = rolling_window(first_derivs)
    second_derivs = np.fromiter(second_d_gen(second_windows), np.float
                                , count=len(second_windows))
    # gets index or position value of inflection point (curves down ), adjust by adding 1
    # for second deriv
    thresh_i = min(np.argmin(second_derivs)+1, len(y_temp)-1)
    thresh_v = y_temp[thresh_i]
    
#     print "min", np.min(second_derivs), np.argmin(second_derivs)
#     print 'max', np.max(second_derivs), np.argmax(second_derivs)
    return thresh_v

# %%
def eliminate_oneoffs(g, thresh_val, pad=True,
                      qtag=QTAG, barcode=BARCODE, passed='passed',
                      barcode_error = 'barcode_error',
                      qtag_error = 'qtag_error',
                      mcounts=MCOUNTS):
    """Eliminate barcodes that are one position off from a more-abundant barcode
        group(pd.DataFrame): df containing qtag, barcode, and percent_mcounts columns
        thresh_val(float): threshold value to select high abundant barcodes
            to iterate through as 'major' ones
        pad(bool): if True, adds a right pad so last non-eliminated value 
            can be analyzed in by the threshold() function. Default True.
        qtag, barcode, percent_mcounts, mcounts (str): column names for the corresponding
            argument. Defaults are global vars QTAG, BARCODE, PERCENT_MCOUNTS, MCOUNTS.

        Returns: table of barcodes that passed elimination
        
        For regex package info, see https://pypi.python.org/pypi/regex/
    """
    g.sort_values(by=mcounts, ascending=False, inplace=True)
    g.loc[g[mcounts] < thresh_val, 'passed'] = False
    g.loc[:,'is_padding'] = False
    failed = []
#     print "elim", len(g), thresh_val, len(g.loc[g['passed']==True]), len( g.loc[(g['passed']==True)&(g[mcounts])>=thresh_val])
#     majors = filter_g.loc[(filter_g[mcounts])>thresh_val]
    i = 0
    # add capability to check other parameters, i.e. qtag
#     for maj_i, maj_r in g.loc[(g['passed']==True)&(g[mcounts])>=thresh_val].iterrows():
    for maj_i, maj_r in g.loc[g['passed']==True].iterrows():
        # if it has not yet been tested
        if g.loc[maj_i,'passed'] == True:
#             print 'passed maj', maj_r[mcounts]
#             minors = filter_g.loc[filter_g[mcounts]<maj_r[mcounts]]

            minors = g.loc[(g['passed']==True)&(g[mcounts]<maj_r[mcounts])]

            # for each 'minor' barcode aka. with fewer molecs, test if one-off from major
            for min_i, min_r in minors.iterrows():
                query = regex.search("(%s){s<=1}"% maj_r[barcode], min_r[barcode])
                if query:
                    g.loc[min_i,'passed'] = False
                    g.loc[min_i,'barcode_error'] += 1 if sum(query.fuzzy_counts)>0 else 0
                    g.loc[min_i,'qtag_error'] += 1 if min_r[qtag]!=maj_r[qtag] else 0
#                     if min_r[mcounts] < thresh_val:
                    failed.append([min_i, min_r[mcounts]])
                                          
            i+=1
                    
#     # if requested, adds a right pad  
#     # line added 2016-10-12: combine two conditions: ensure that 
#     # no null rows get added if all barcodes are accepted
#     g.loc[:,'passed'] = g.apply(lambda x: False if g.index in failed else x['passed'], axis=1)
#     print len(g), len(g.loc[g['passed']==False]), len(failed)
#     print "THR VAL",thresh_val
#     print g
#     print g['passed']==False
    if len(failed) > 0:
        failed.sort(key=lambda x: x[1])
        failed = failed[::-1]
    
#     if pad==True and len(failed) > 0:
    if pad==True and len(g) != len(g.loc[g['passed']==False]):
        pad_i = [f[0] for f in failed[:1]]
        pad_i = g.loc[(g['passed']==False),mcounts][:1].index.values
#         print "PADI", pad_i
        for pi in pad_i:
            g.loc[pi,'is_padding'] = True
#         print "PADI ADJ"
#         print g
    return g

# %%
def run_threshold(d, sample=SAMPLE, qtag=QTAG, barcode=BARCODE, 
                  mcounts=MCOUNTS, reads=READS, percent_mcounts=PERCENT_MCOUNTS,
                  min_reads=MIN_READS, min_mcount=50):
    """Run threshold algorithm for each sample in dataset

        d(np.array, list, dict, or pd.DataFrame): dataset for all samples
        sample, qtag, barcode, mcounts, reads, percent_mcounts(str): columns in df for 
            corresponding vals. Defaults are global vars SAMPLE, QTAG, BARCODE, MCOUNTS, 
            READS, PERCENT_MCOUNTS.
        min_reads(int): minimum number of reads for a library-ID-barcode as an 
            absolute baseline (that which any barcode below is highly likely to be 
            false.) Default is global var MIN_READS.
        min_mcount(int): minimum number of molecs for library-ID-barcode as an
            absolute baseline. Default is 50.

        Note: min_reads and min_mcount are applied to increase performance.

        Returns: 
            pd.DataFrame, if successful, of 'true' (passed) library-ID-barcodes 
                for all samples
            None, if no samples had passing library-ID-barcodes.
    """
    passed = []
    all_threshold_logs = {}
    counter = 1
    # checks and formats data (d) to list-like obj of pairs
    data_arr = check_data(d, sample=sample, mcounts=mcounts, reads=reads)
    # run for each (sample, df) in dataset 
    for s, group in data_arr:
        sys.stdout.write("\n-------------\nSample %d of %d (%s): "%(counter,len(data_arr),s))
        # select valid data meeting absolute baseline 
        g = group.loc[(group[qtag] != 'None') & (group[barcode] != 'None') 
                          & (group[mcounts] > min_mcount)]
#                           & (group[reads] > min_reads)]
        if len(g)>0:
            g.loc[:,'passed'] = True
            g.loc[:,'qtag_error'] = False
            g.loc[:,'barcode_error'] = False
            g.loc[:,'is_padding'] = False
            result, tlogs = threshold(g, 20, -1, [])
            passed.append(result)
            all_threshold_logs[s] = tlogs
        sys.stdout.flush()
        counter += 1


    # if we do have data (i.e. some barcodes that passed in the samples)
    if len(passed) > 0:
        # concat all df together
        passeddf = pd.concat(passed)
        passeddf.sort_values(by=[sample,percent_mcounts]
                             ,ascending=[True, False]
                             ,inplace=True)
        passeddf.reset_index(inplace=True,drop=True)
        return passeddf, all_threshold_logs
    else:
        print "No samples were successfully thresholded."
    return

# %% [markdown]
# ### SCRIPT TO SAVE DATA TO CSVs

# %%
def save_data(filtered,passed, output_directory=OUTPUT_DIRECTORY, experiment=EXPERIMENT):
    
    # Save passed dataframe
    passed.to_csv('%s/threshold-%s-passed.csv'%(output_directory,experiment), index=False)
    # count and save results
    counts = count_sample_barcodes(passed)
    counts.to_csv('%s/threshold-%s-counts.csv'%(output_directory,experiment), index=False)
    # merge passed and filtered data and save
    fc_temp = pd.concat([d[1] for d in filtered])
    filtered_concat = apply_passed_data(fc_temp, passed)
    filtered_concat.to_csv('%s/threshold-%s-merged.csv'%(output_directory,experiment), index=False)

# %%
def count_sample_barcodes(df, groupby=SAMPLE, barcode=BARCODE, sample=SAMPLE, qtag=QTAG
                      , percent_mcounts=PERCENT_MCOUNTS):
    """Counts passed barcodes per sample and saves as csv
    
        df(pd.DataFrame): input dataframe containing passed 
            barcodes of all samples
        groupby(str or list-like): columns to group samples by
    """
    agg = df.groupby(groupby).agg(len)
    counts = agg[agg.columns[0]]
    counts.name = 'count'
    counts = pd.DataFrame(counts)
    counts.reset_index(inplace=True)
    return counts

# %%
def apply_passed_data(filtered, passeddf, sample=SAMPLE, qtag=QTAG
                      , barcode=BARCODE, percent_mcounts=PERCENT_MCOUNTS):
    """Cross reference passed barcodes with raw filtered data
        filtered(pd.DataFrame): raw filtered data as dataframe for all samples
        passed(pd.DataFrame): data passed threshold (output of run_threshold)
        sample,qtag,barcode,percent_mcounts(str): names corresponding to df columns.
            Defaults are SAMPLE,QTAG,BARCODE,PERCENT_MCOUNTS.

        Returns:
            filtered(pd.DataFrame) updated with 'passed_threshold' and 
            percent_mcounts columns
    """
    def cross_ref_passed(row):
        key = (row[sample],row[qtag],row[barcode])
        if key in passed_indexed.index:
            row.loc[:,percent_mcounts+'_thresholded'] = passed_indexed.loc[key,percent_mcounts]
            row.loc[:,'passed_threshold'] = True
        return row

    passed_indexed = passeddf.set_index([sample,qtag,barcode])
    filtered.rename(columns={percent_mcounts:percent_mcounts+'_filtered'})
    filtered.loc[:,'passed_threshold'] = False
    filtered.loc[:,percent_mcounts+'_thresholded'] = 0
    filtered = filtered.apply(cross_ref_passed, axis=1)
    return filtered

# %% [markdown]
# # EXECUTE SCRIPT BELOW

# %%
if __name__=='__main__':
    # Check all inputs exist and are valid
    check_inputs()
    # Runs data loading in script
    filtered = load_data(FILTERED_FILEPATH)
    # Run thresholding of all samples in dataset
    passeddf, all_threshold_logs = run_threshold(filtered)
#     save_data(filtered, passeddf, output_directory=OUTPUT_DIRECTORY, experiment=EXPERIMENT)
# Out:
# C:\Users\vwl698\Anaconda2\lib\site-packages\ipykernel\__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -------------
# Sample 1 of 27 (1):
# C:\Users\vwl698\Anaconda2\lib\site-packages\ipykernel\__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\vwl698\Anaconda2\lib\site-packages\ipykernel\__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 20 5
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 140  q19  GGGCGGC      79618   True      False
# 141  q19  GGGCGAC        266   True      False
# 142  q19  GGGCAGC        152   True      False
# 143  q19  GGGTGGC         55   True      False
# 144  q19  GGACGGC         52   True      False
# new 266
#     qtag  barcode  mcountsPF passed is_padding
# 140  q19  GGGCGGC      79618   True      False
# 141  q19  GGGCGAC        266   True      False
#
# 19 5
# old 266
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      79618   True      False
# 1  q19  GGGCGAC        266  False       True
# new 266
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      79618   True      False
# 1  q19  GGGCGAC        266  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      79618   True      False
# C:\Users\vwl698\Anaconda2\lib\site-packages\ipykernel\__main__.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# FINAL 1
# Thresholded.
#
# -------------
# Sample 2 of 27 (10):
# 20 14
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 983  q24  CCAGTTG      41816   True      False
# 984  q24  ATTCGCT      15702   True      False
# 985  q25  ACAATGA       9662   True      False
# 986  q24  ACAATGA       2339   True      False
# 987  q25  CCAGTTG       2249   True      False
# 988  q24  CCCGTTG       1520   True      False
# 989  q25  ATTCGCT        829   True      False
# 990  q24  CTTCGCT        538   True      False
# 991  q25  CCAATGA        333   True      False
# 992  q25  ACCATGA        281   True      False
# 993  q25  CCCGTTG         85   True      False
# 994  q24  CCAATGA         82   True      False
# 995  q24  ACCATGA         63   True      False
# 996  q24  CCAGTTT         63   True      False
# new 15702
#     qtag  barcode  mcountsPF passed is_padding
# 983  q24  CCAGTTG      41816   True      False
# 984  q24  ATTCGCT      15702   True      False
#
# 19 14
# old 15702
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CCAGTTG      41816   True      False
# 1  q24  ATTCGCT      15702   True      False
# new 15702
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CCAGTTG      41816   True      False
# 1  q24  ATTCGCT      15702   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CCAGTTG      41816   True      False
# 1  q24  ATTCGCT      15702   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 3 of 27 (11):
# 20 5
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 931  q26  CGTAAAC      81232   True      False
# 932  q27  GCGGTAG       7883   True      False
# 933  q27  CGTAAAC       3772   True      False
# 934  q26  GCGGTAG       1118   True      False
# 935  q26  CGCAAAC         76   True      False
# new 7883
#     qtag  barcode  mcountsPF passed is_padding
# 931  q26  CGTAAAC      81232   True      False
# 932  q27  GCGGTAG       7883   True      False
#
# 19 5
# old 7883
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGTAAAC      81232   True      False
# 1  q27  GCGGTAG       7883   True      False
# new 7883
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGTAAAC      81232   True      False
# 1  q27  GCGGTAG       7883   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGTAAAC      81232   True      False
# 1  q27  GCGGTAG       7883   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 4 of 27 (12):
# 20 7
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1121  q19  CTGGCGT      78535   True      False
# 1122  q24  GCTTTAG       3712   True      False
# 1123  q24  CTGGCGT       2300   True      False
# 1124  q19  GCTTTAG        755   True      False
# 1125  q19  CTGGCAT        126   True      False
# 1126  q19  CTGACGT        101   True      False
# 1127  q19  CTGGCGC         91   True      False
# new 3712
#      qtag  barcode  mcountsPF passed is_padding
# 1121  q19  CTGGCGT      78535   True      False
# 1122  q24  GCTTTAG       3712   True      False
#
# 19 7
# old 3712
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CTGGCGT      78535   True      False
# 1  q24  GCTTTAG       3712   True      False
# new 3712
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CTGGCGT      78535   True      False
# 1  q24  GCTTTAG       3712   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CTGGCGT      78535   True      False
# 1  q24  GCTTTAG       3712   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 5 of 27 (13):
# 20 5
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1072  q25  CCCGTCT      69129   True      False
# 1073  q26  CATATAT        200   True      False
# 1074  q26  CCCGTCT        142   True      False
# 1075  q25  CCCATCT         90   True      False
# 1076  q25  CCCGTCC         60   True      False
# new 200
#      qtag  barcode  mcountsPF passed is_padding
# 1072  q25  CCCGTCT      69129   True      False
# 1073  q26  CATATAT        200   True      False
#
# 19 5
# old 200
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  CCCGTCT      69129   True      False
# 1  q26  CATATAT        200   True      False
# new 200
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  CCCGTCT      69129   True      False
# 1  q26  CATATAT        200   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  CCCGTCT      69129   True      False
# 1  q26  CATATAT        200   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 6 of 27 (14):
# 20 12
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 841  q19  GGGCGGC      21111   True      False
# 842  q27  CGCATAG      16209   True      False
# 843  q24  CAGAAGT      14354   True      False
# 844  q24  GGGCGGC       1820   True      False
# 845  q27  GGGCGGC       1689   True      False
# 846  q24  CGCATAG       1400   True      False
# 847  q19  CGCATAG       1332   True      False
# 848  q19  CAGAAGT       1306   True      False
# 849  q27  CAGAAGT       1239   True      False
# 850  q24  CCGAAGT        476   True      False
# 851  q19  CCGAAGT         65   True      False
# 852  q19  GGGCGAC         57   True      False
# new 1820
#     qtag  barcode  mcountsPF passed is_padding
# 841  q19  GGGCGGC      21111   True      False
# 842  q27  CGCATAG      16209   True      False
# 843  q24  CAGAAGT      14354   True      False
# 844  q24  GGGCGGC       1820   True      False
#
# 19 12
# old 1820
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      21111   True      False
# 1  q27  CGCATAG      16209   True      False
# 2  q24  CAGAAGT      14354   True      False
# 3  q24  GGGCGGC       1820  False       True
# new 1820
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      21111   True      False
# 1  q27  CGCATAG      16209   True      False
# 2  q24  CAGAAGT      14354   True      False
# 3  q24  GGGCGGC       1820  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      21111   True      False
# 1  q27  CGCATAG      16209   True      False
# 2  q24  CAGAAGT      14354   True      False
# FINAL 3
# Thresholded.
#
# -------------
# Sample 7 of 27 (15):
# 20 12
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1164  q25  GGAGCCA      17705   True      False
# 1165  q27  GAGGAGT      10116   True      False
# 1166  q26  CGCTTTG       9665   True      False
# 1167  q27  GGAGCCA       1629   True      False
# 1168  q26  GGAGCCA       1290   True      False
# 1169  q25  CGCTTTG       1124   True      False
# 1170  q25  GAGGAGT       1003   True      False
# 1171  q27  CGCTTTG        902   True      False
# 1172  q26  GAGGAGT        714   True      False
# 1173  q25  GGCGCCA        450   True      False
# 1174  q27  GCGGAGT        303   True      False
# 1175  q25  GGAACCA         52   True      False
# new 1629
#      qtag  barcode  mcountsPF passed is_padding
# 1164  q25  GGAGCCA      17705   True      False
# 1165  q27  GAGGAGT      10116   True      False
# 1166  q26  CGCTTTG       9665   True      False
# 1167  q27  GGAGCCA       1629   True      False
#
# 19 12
# old 1629
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  GGAGCCA      17705   True      False
# 1  q27  GAGGAGT      10116   True      False
# 2  q26  CGCTTTG       9665   True      False
# 3  q27  GGAGCCA       1629  False       True
# new 1629
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  GGAGCCA      17705   True      False
# 1  q27  GAGGAGT      10116   True      False
# 2  q26  CGCTTTG       9665   True      False
# 3  q27  GGAGCCA       1629  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  GGAGCCA      17705   True      False
# 1  q27  GAGGAGT      10116   True      False
# 2  q26  CGCTTTG       9665   True      False
# FINAL 3
# Thresholded.
#
# -------------
# Sample 8 of 27 (16):
# 20 16
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1475  q19  CCGCCTG      35493   True      False
# 1476  q25  ACAATGA       6945   True      False
# 1477  q24  CCAGTTG       4664   True      False
# 1478  q24  CCGCCTG       1934   True      False
# 1479  q25  CCGCCTG       1892   True      False
# 1480  q24  ATTCGCT       1557   True      False
# 1481  q19  ACAATGA       1214   True      False
# 1482  q19  CCAGTTG        847   True      False
# 1483  q24  ACAATGA        519   True      False
# 1484  q25  CCAGTTG        301   True      False
# 1485  q19  ATTCGCT        245   True      False
# 1486  q25  CCAATGA        235   True      False
# 1487  q25  ACCATGA        203   True      False
# 1488  q24  CCCGTTG        162   True      False
# 1489  q25  ATTCGCT        107   True      False
# 1490  q24  CTTCGCT         56   True      False
# new 6945
#      qtag  barcode  mcountsPF passed is_padding
# 1475  q19  CCGCCTG      35493   True      False
# 1476  q25  ACAATGA       6945   True      False
#
# 19 16
# old 6945
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CCGCCTG      35493   True      False
# 1  q25  ACAATGA       6945   True      False
# new 6945
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CCGCCTG      35493   True      False
# 1  q25  ACAATGA       6945   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CCGCCTG      35493   True      False
# 1  q25  ACAATGA       6945   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 9 of 27 (17):
# 20 18
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1406  q19  CTGGCGT       5933   True      False
# 1407  q24  GCTTTAG       5218   True      False
# 1408  q26  CGTAAAC       2852   True      False
# 1409  q27  GCGGTAG       2653   True      False
# 1410  q24  CTGGCGT        636   True      False
# 1411  q24  CGTAAAC        386   True      False
# 1412  q19  GCTTTAG        384   True      False
# 1413  q24  GCGGTAG        369   True      False
# 1414  q27  CTGGCGT        350   True      False
# 1415  q19  CGTAAAC        329   True      False
# 1416  q27  GCTTTAG        327   True      False
# 1417  q26  CTGGCGT        272   True      False
# 1418  q25  GGAGCCA        268   True      False
# 1419  q19  GCGGTAG        250   True      False
# 1420  q26  GCTTTAG        235   True      False
# 1421  q27  CGTAAAC        211   True      False
# 1422  q26  GCGGTAG        124   True      False
# 1423  q24  GGAGCCA         55   True      False
# new 636
#      qtag  barcode  mcountsPF passed is_padding
# 1406  q19  CTGGCGT       5933   True      False
# 1407  q24  GCTTTAG       5218   True      False
# 1408  q26  CGTAAAC       2852   True      False
# 1409  q27  GCGGTAG       2653   True      False
# 1410  q24  CTGGCGT        636   True      False
#
# 19 18
# old 636
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CTGGCGT       5933   True      False
# 1  q24  GCTTTAG       5218   True      False
# 2  q26  CGTAAAC       2852   True      False
# 3  q27  GCGGTAG       2653   True      False
# 4  q24  CTGGCGT        636  False       True
# new 636
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CTGGCGT       5933   True      False
# 1  q24  GCTTTAG       5218   True      False
# 2  q26  CGTAAAC       2852   True      False
# 3  q27  GCGGTAG       2653   True      False
# 4  q24  CTGGCGT        636  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CTGGCGT       5933   True      False
# 1  q24  GCTTTAG       5218   True      False
# 2  q26  CGTAAAC       2852   True      False
# 3  q27  GCGGTAG       2653   True      False
# FINAL 4
# Thresholded.
#
# -------------
# Sample 10 of 27 (18):
# 20 28
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1731  q19  GGGCGGC      14184   True      False
# 1732  q24  CAGAAGT      11074   True      False
# 1733  q27  CGCATAG      10387   True      False
# 1734  q26  CATATAT       6461   True      False
# 1735  q25  GGAGCCA       2844   True      False
# 1736  q24  GGGCGGC       1219   True      False
# 1737  q27  GGGCGGC        947   True      False
# 1738  q24  CGCATAG        851   True      False
# 1739  q19  CAGAAGT        776   True      False
# 1740  q27  CAGAAGT        732   True      False
# 1741  q19  CGCATAG        665   True      False
# 1742  q26  GGGCGGC        592   True      False
# 1743  q24  CATATAT        557   True      False
# 1744  q19  CATATAT        513   True      False
# 1745  q26  CAGAAGT        458   True      False
# 1746  q27  CATATAT        451   True      False
# 1747  q26  CGCATAG        396   True      False
# 1748  q24  CCGAAGT        384   True      False
# 1749  q25  GGGCGGC        362   True      False
# 1750  q19  GGAGCCA        283   True      False
# 1751  q24  GGAGCCA        269   True      False
# 1752  q25  CGCATAG        251   True      False
# 1753  q25  CAGAAGT        248   True      False
# 1754  q27  GGAGCCA        230   True      False
# 1755  q26  CCTATAT        201   True      False
# 1756  q26  GGAGCCA        190   True      False
# 1757  q25  CATATAT        180   True      False
# 1758  q25  GGCGCCA         77   True      False
# new 77
#      qtag  barcode  mcountsPF passed is_padding
# 1731  q19  GGGCGGC      14184   True      False
# 1732  q24  CAGAAGT      11074   True      False
# 1733  q27  CGCATAG      10387   True      False
# 1734  q26  CATATAT       6461   True      False
# 1735  q25  GGAGCCA       2844   True      False
# 1736  q24  GGGCGGC       1219   True      False
# 1737  q27  GGGCGGC        947   True      False
# 1738  q24  CGCATAG        851   True      False
# 1739  q19  CAGAAGT        776   True      False
# 1740  q27  CAGAAGT        732   True      False
# 1741  q19  CGCATAG        665   True      False
# 1742  q26  GGGCGGC        592   True      False
# 1743  q24  CATATAT        557   True      False
# 1744  q19  CATATAT        513   True      False
# 1745  q26  CAGAAGT        458   True      False
# 1746  q27  CATATAT        451   True      False
# 1747  q26  CGCATAG        396   True      False
# 1748  q24  CCGAAGT        384   True      False
# 1749  q25  GGGCGGC        362   True      False
# 1750  q19  GGAGCCA        283   True      False
# 1751  q24  GGAGCCA        269   True      False
# 1752  q25  CGCATAG        251   True      False
# 1753  q25  CAGAAGT        248   True      False
# 1754  q27  GGAGCCA        230   True      False
# 1755  q26  CCTATAT        201   True      False
# 1756  q26  GGAGCCA        190   True      False
# 1757  q25  CATATAT        180   True      False
# 1758  q25  GGCGCCA         77   True      False
#
# 19 28
# old 77
#    qtag  barcode  mcountsPF passed is_padding
# 0   q19  GGGCGGC      14184   True      False
# 1   q24  CAGAAGT      11074   True      False
# 2   q27  CGCATAG      10387   True      False
# 3   q26  CATATAT       6461   True      False
# 4   q25  GGAGCCA       2844   True      False
# 5   q24  GGGCGGC       1219  False       True
# 6   q27  GGGCGGC        947  False      False
# 7   q24  CGCATAG        851  False      False
# 8   q19  CAGAAGT        776  False      False
# 9   q27  CAGAAGT        732  False      False
# 10  q19  CGCATAG        665  False      False
# 11  q26  GGGCGGC        592  False      False
# 12  q24  CATATAT        557  False      False
# 13  q19  CATATAT        513  False      False
# 14  q26  CAGAAGT        458  False      False
# 15  q27  CATATAT        451  False      False
# 16  q26  CGCATAG        396  False      False
# 17  q24  CCGAAGT        384  False      False
# 18  q25  GGGCGGC        362  False      False
# 19  q19  GGAGCCA        283  False      False
# 20  q24  GGAGCCA        269  False      False
# 21  q25  CGCATAG        251  False      False
# 22  q25  CAGAAGT        248  False      False
# 23  q27  GGAGCCA        230  False      False
# 24  q26  CCTATAT        201  False      False
# 25  q26  GGAGCCA        190  False      False
# 26  q25  CATATAT        180  False      False
# 27  q25  GGCGCCA         77  False      False
# new 6461
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      14184   True      False
# 1  q24  CAGAAGT      11074   True      False
# 2  q27  CGCATAG      10387   True      False
# 3  q26  CATATAT       6461   True      False
#
# 18 28
# old 6461
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      14184   True      False
# 1  q24  CAGAAGT      11074   True      False
# 2  q27  CGCATAG      10387   True      False
# 3  q26  CATATAT       6461   True      False
# new 6461
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      14184   True      False
# 1  q24  CAGAAGT      11074   True      False
# 2  q27  CGCATAG      10387   True      False
# 3  q26  CATATAT       6461   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      14184   True      False
# 1  q24  CAGAAGT      11074   True      False
# 2  q27  CGCATAG      10387   True      False
# 3  q26  CATATAT       6461   True      False
# FINAL 4
# Thresholded.
#
# -------------
# Sample 11 of 27 (19):
# 20 35
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1569  q19  CCGCCTG       7671   True      False
# 1570  q26  CGCTTTG       6449   True      False
# 1571  q24  CCAGTTG       5745   True      False
# 1572  q27  GAGGAGT       5450   True      False
# 1573  q25  ACAATGA       3677   True      False
# 1574  q24  ATTCGCT       1833   True      False
# 1575  q24  CCGCCTG        702   True      False
# 1576  q24  CGCTTTG        631   True      False
# 1577  q19  CGCTTTG        579   True      False
# 1578  q26  CCGCCTG        486   True      False
# 1579  q24  GAGGAGT        480   True      False
# 1580  q27  CCGCCTG        421   True      False
# 1581  q27  CGCTTTG        410   True      False
# 1582  q19  CCAGTTG        381   True      False
# 1583  q19  GAGGAGT        365   True      False
# 1584  q24  ACAATGA        352   True      False
# 1585  q25  CCGCCTG        348   True      False
# 1586  q27  CCAGTTG        342   True      False
# 1587  q26  CCAGTTG        308   True      False
# 1588  q25  CGCTTTG        306   True      False
# 1589  q26  GAGGAGT        300   True      False
# 1590  q19  ACAATGA        262   True      False
# 1591  q25  GAGGAGT        237   True      False
# 1592  q25  CCAGTTG        228   True      False
# 1593  q27  ACAATGA        222   True      False
# 1594  q26  ACAATGA        219   True      False
# 1595  q24  CCCGTTG        171   True      False
# 1596  q27  GCGGAGT        158   True      False
# 1597  q19  ATTCGCT        119   True      False
# 1598  q25  CCAATGA        102   True      False
# 1599  q25  ACCATGA         96   True      False
# 1600  q26  ATTCGCT         91   True      False
# 1601  q27  ATTCGCT         86   True      False
# 1602  q25  ATTCGCT         75   True      False
# 1603  q24  CTTCGCT         57   True      False
# new 3677
#      qtag  barcode  mcountsPF passed is_padding
# 1569  q19  CCGCCTG       7671   True      False
# 1570  q26  CGCTTTG       6449   True      False
# 1571  q24  CCAGTTG       5745   True      False
# 1572  q27  GAGGAGT       5450   True      False
# 1573  q25  ACAATGA       3677   True      False
#
# 19 35
# old 3677
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CCGCCTG       7671   True      False
# 1  q26  CGCTTTG       6449   True      False
# 2  q24  CCAGTTG       5745   True      False
# 3  q27  GAGGAGT       5450   True      False
# 4  q25  ACAATGA       3677   True      False
# new 3677
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CCGCCTG       7671   True      False
# 1  q26  CGCTTTG       6449   True      False
# 2  q24  CCAGTTG       5745   True      False
# 3  q27  GAGGAGT       5450   True      False
# 4  q25  ACAATGA       3677   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  CCGCCTG       7671   True      False
# 1  q26  CGCTTTG       6449   True      False
# 2  q24  CCAGTTG       5745   True      False
# 3  q27  GAGGAGT       5450   True      False
# 4  q25  ACAATGA       3677   True      False
# FINAL 5
# Thresholded.
#
# -------------
# Sample 12 of 27 (2):
# 20 3
# old -1
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CAGAAGT      75662   True      False
# 1  q24  CCGAAGT       3037   True      False
# 2  q24  CAGAAGC         57   True      False
# new 3037
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CAGAAGT      75662   True      False
# 1  q24  CCGAAGT       3037   True      False
#
# 19 3
# old 3037
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CAGAAGT      75662   True      False
# 1  q24  CCGAAGT       3037  False       True
# new 3037
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CAGAAGT      75662   True      False
# 1  q24  CCGAAGT       3037  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  CAGAAGT      75662   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 13 of 27 (20):
# 20 24
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 774  q24  GCTTTAG       3079   True      False
# 775  q19  CTGGCGT       2885   True      False
# 776  q25  CCCGTCT       2518   True      False
# 777  q26  CGTAAAC       1578   True      False
# 778  q27  GCGGTAG       1072   True      False
# 779  q24  CTGGCGT        250   True      False
# 780  q24  CCCGTCT        241   True      False
# 781  q25  CTGGCGT        188   True      False
# 782  q19  CCCGTCT        182   True      False
# 783  q19  GCTTTAG        166   True      False
# 785  q24  CGTAAAC        162   True      False
# 784  q25  GCTTTAG        162   True      False
# 787  q24  GCGGTAG        142   True      False
# 786  q19  CGTAAAC        142   True      False
# 788  q27  GCTTTAG        128   True      False
# 789  q27  CTGGCGT        117   True      False
# 790  q26  CTGGCGT        116   True      False
# 791  q25  CGTAAAC        110   True      False
# 792  q27  CCCGTCT        106   True      False
# 793  q26  GCTTTAG         98   True      False
# 794  q26  CCCGTCT         94   True      False
# 795  q25  GCGGTAG         83   True      False
# 796  q19  GCGGTAG         75   True      False
# 797  q27  CGTAAAC         65   True      False
# new 250
#     qtag  barcode  mcountsPF passed is_padding
# 774  q24  GCTTTAG       3079   True      False
# 775  q19  CTGGCGT       2885   True      False
# 776  q25  CCCGTCT       2518   True      False
# 777  q26  CGTAAAC       1578   True      False
# 778  q27  GCGGTAG       1072   True      False
# 779  q24  CTGGCGT        250   True      False
#
# 19 24
# old 250
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCTTTAG       3079   True      False
# 1  q19  CTGGCGT       2885   True      False
# 2  q25  CCCGTCT       2518   True      False
# 3  q26  CGTAAAC       1578   True      False
# 4  q27  GCGGTAG       1072   True      False
# 5  q24  CTGGCGT        250  False       True
# new 250
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCTTTAG       3079   True      False
# 1  q19  CTGGCGT       2885   True      False
# 2  q25  CCCGTCT       2518   True      False
# 3  q26  CGTAAAC       1578   True      False
# 4  q27  GCGGTAG       1072   True      False
# 5  q24  CTGGCGT        250  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCTTTAG       3079   True      False
# 1  q19  CTGGCGT       2885   True      False
# 2  q25  CCCGTCT       2518   True      False
# 3  q26  CGTAAAC       1578   True      False
# 4  q27  GCGGTAG       1072   True      False
# FINAL 5
# Thresholded.
#
# -------------
# Sample 14 of 27 (21):
# 20 28
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1989  q26  CATATAT      17785   True      False
# 1990  q19  GGGCGGC       7552   True      False
# 1991  q25  GGAGCCA       5876   True      False
# 1992  q24  CAGAAGT       5546   True      False
# 1993  q27  CGCATAG       5374   True      False
# 1994  q24  CATATAT        859   True      False
# 1995  q19  CATATAT        790   True      False
# 1996  q27  CATATAT        774   True      False
# 1997  q25  CATATAT        706   True      False
# 1998  q26  GGGCGGC        672   True      False
# 1999  q26  CCTATAT        658   True      False
# 2000  q26  GGAGCCA        507   True      False
# 2001  q26  CAGAAGT        453   True      False
# 2002  q26  CGCATAG        451   True      False
# 2003  q25  GGGCGGC        381   True      False
# 2004  q27  GGGCGGC        363   True      False
# 2005  q24  GGGCGGC        352   True      False
# 2006  q19  GGAGCCA        324   True      False
# 2007  q27  GGAGCCA        290   True      False
# 2008  q24  GGAGCCA        281   True      False
# 2009  q24  CGCATAG        247   True      False
# 2010  q19  CAGAAGT        246   True      False
# 2011  q19  CGCATAG        234   True      False
# 2012  q25  CGCATAG        208   True      False
# 2013  q25  CAGAAGT        199   True      False
# 2014  q24  CCGAAGT        194   True      False
# 2015  q27  CAGAAGT        193   True      False
# 2016  q25  GGCGCCA        165   True      False
# new 859
#      qtag  barcode  mcountsPF passed is_padding
# 1989  q26  CATATAT      17785   True      False
# 1990  q19  GGGCGGC       7552   True      False
# 1991  q25  GGAGCCA       5876   True      False
# 1992  q24  CAGAAGT       5546   True      False
# 1993  q27  CGCATAG       5374   True      False
# 1994  q24  CATATAT        859   True      False
#
# 19 28
# old 859
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CATATAT      17785   True      False
# 1  q19  GGGCGGC       7552   True      False
# 2  q25  GGAGCCA       5876   True      False
# 3  q24  CAGAAGT       5546   True      False
# 4  q27  CGCATAG       5374   True      False
# 5  q24  CATATAT        859  False       True
# new 859
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CATATAT      17785   True      False
# 1  q19  GGGCGGC       7552   True      False
# 2  q25  GGAGCCA       5876   True      False
# 3  q24  CAGAAGT       5546   True      False
# 4  q27  CGCATAG       5374   True      False
# 5  q24  CATATAT        859  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CATATAT      17785   True      False
# 1  q19  GGGCGGC       7552   True      False
# 2  q25  GGAGCCA       5876   True      False
# 3  q24  CAGAAGT       5546   True      False
# 4  q27  CGCATAG       5374   True      False
# FINAL 5
# Thresholded.
#
# -------------
# Sample 15 of 27 (22):
# 20 32
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1255  q26  CGCTTTG      40450   True      False
# 1256  q25  ACAATGA       4369   True      False
# 1257  q27  GAGGAGT       4094   True      False
# 1258  q19  CCGCCTG       3575   True      False
# 1259  q24  CCAGTTG       3413   True      False
# 1260  q25  CGCTTTG       1314   True      False
# 1261  q24  CGCTTTG       1306   True      False
# 1262  q27  CGCTTTG       1139   True      False
# 1263  q24  ATTCGCT       1080   True      False
# 1264  q19  CGCTTTG        972   True      False
# 1265  q26  ACAATGA        606   True      False
# 1266  q26  GAGGAGT        525   True      False
# 1267  q26  CCGCCTG        509   True      False
# 1268  q26  CCAGTTG        505   True      False
# 1269  q24  ACAATGA        207   True      False
# 1270  q25  GAGGAGT        173   True      False
# 1271  q24  GAGGAGT        162   True      False
# 1272  q27  ACAATGA        150   True      False
# 1273  q24  CCGCCTG        142   True      False
# 1274  q25  CCAATGA        141   True      False
# 1275  q25  ACCATGA        138   True      False
# 1276  q25  CCGCCTG        133   True      False
# 1277  q19  ACAATGA        131   True      False
# 1278  q25  CCAGTTG        130   True      False
# 1279  q27  CCAGTTG        128   True      False
# 1280  q26  ATTCGCT        124   True      False
# 1281  q27  GCGGAGT        120   True      False
# 1282  q27  CCGCCTG        118   True      False
# 1283  q19  CCAGTTG        107   True      False
# 1284  q24  CCCGTTG         93   True      False
# 1285  q19  GAGGAGT         79   True      False
# 1286  q26  CGCTTTT         58   True      False
# new 4369
#      qtag  barcode  mcountsPF passed is_padding
# 1255  q26  CGCTTTG      40450   True      False
# 1256  q25  ACAATGA       4369   True      False
#
# 19 32
# old 4369
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGCTTTG      40450   True      False
# 1  q25  ACAATGA       4369   True      False
# new 4369
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGCTTTG      40450   True      False
# 1  q25  ACAATGA       4369   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGCTTTG      40450   True      False
# 1  q25  ACAATGA       4369   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 16 of 27 (23):
# 20 22
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1878  q27  GCGGTAG      37849   True      False
# 1879  q19  CTGGCGT       3774   True      False
# 1880  q25  CCCGTCT       2643   True      False
# 1881  q24  GCTTTAG       2635   True      False
# 1882  q26  CGTAAAC       1234   True      False
# 1883  q24  GCGGTAG       1212   True      False
# 1884  q19  GCGGTAG       1095   True      False
# 1885  q25  GCGGTAG        733   True      False
# 1886  q27  CTGGCGT        629   True      False
# 1887  q27  GCTTTAG        515   True      False
# 1888  q27  CCCGTCT        460   True      False
# 1889  q26  GCGGTAG        358   True      False
# 1890  q27  CGTAAAC        260   True      False
# 1891  q24  CTGGCGT        133   True      False
# 1892  q25  CTGGCGT        111   True      False
# 1893  q24  CCCGTCT        107   True      False
# 1894  q19  CCCGTCT         98   True      False
# 1895  q19  GCTTTAG         79   True      False
# 1896  q19  CGTAAAC         72   True      False
# 1897  q25  GCTTTAG         68   True      False
# 1898  q24  CGTAAAC         66   True      False
# 1899  q27  GCAGTAG         54   True      False
# new 3774
#      qtag  barcode  mcountsPF passed is_padding
# 1878  q27  GCGGTAG      37849   True      False
# 1879  q19  CTGGCGT       3774   True      False
#
# 19 22
# old 3774
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GCGGTAG      37849   True      False
# 1  q19  CTGGCGT       3774   True      False
# new 3774
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GCGGTAG      37849   True      False
# 1  q19  CTGGCGT       3774   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GCGGTAG      37849   True      False
# 1  q19  CTGGCGT       3774   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 17 of 27 (24):
# 20 28
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 454  q19  GGGCGGC      12299   True      False
# 455  q27  CGCATAG      11083   True      False
# 456  q26  CATATAT       7881   True      False
# 457  q24  CAGAAGT       7192   True      False
# 458  q25  GGAGCCA       5512   True      False
# 459  q27  GGGCGGC       1029   True      False
# 460  q24  GGGCGGC        864   True      False
# 461  q19  CGCATAG        759   True      False
# 462  q24  CGCATAG        746   True      False
# 463  q26  GGGCGGC        683   True      False
# 464  q27  CATATAT        668   True      False
# 465  q25  GGGCGGC        628   True      False
# 466  q26  CGCATAG        620   True      False
# 467  q19  CATATAT        610   True      False
# 468  q19  GGAGCCA        545   True      False
# 469  q24  CATATAT        522   True      False
# 470  q27  GGAGCCA        511   True      False
# 471  q27  CAGAAGT        486   True      False
# 472  q19  CAGAAGT        480   True      False
# 473  q25  CGCATAG        450   True      False
# 474  q26  CAGAAGT        384   True      False
# 475  q25  CATATAT        375   True      False
# 476  q24  GGAGCCA        360   True      False
# 477  q26  GGAGCCA        347   True      False
# 478  q26  CCTATAT        286   True      False
# 479  q25  CAGAAGT        253   True      False
# 480  q24  CCGAAGT        239   True      False
# 481  q25  GGCGCCA        152   True      False
# new 1029
#     qtag  barcode  mcountsPF passed is_padding
# 454  q19  GGGCGGC      12299   True      False
# 455  q27  CGCATAG      11083   True      False
# 456  q26  CATATAT       7881   True      False
# 457  q24  CAGAAGT       7192   True      False
# 458  q25  GGAGCCA       5512   True      False
# 459  q27  GGGCGGC       1029   True      False
#
# 19 28
# old 1029
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      12299   True      False
# 1  q27  CGCATAG      11083   True      False
# 2  q26  CATATAT       7881   True      False
# 3  q24  CAGAAGT       7192   True      False
# 4  q25  GGAGCCA       5512   True      False
# 5  q27  GGGCGGC       1029  False       True
# new 1029
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      12299   True      False
# 1  q27  CGCATAG      11083   True      False
# 2  q26  CATATAT       7881   True      False
# 3  q24  CAGAAGT       7192   True      False
# 4  q25  GGAGCCA       5512   True      False
# 5  q27  GGGCGGC       1029  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      12299   True      False
# 1  q27  CGCATAG      11083   True      False
# 2  q26  CATATAT       7881   True      False
# 3  q24  CAGAAGT       7192   True      False
# 4  q25  GGAGCCA       5512   True      False
# FINAL 5
# Thresholded.
#
# -------------
# Sample 18 of 27 (25):
# 20 33
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 596  q26  CGCTTTG      19390   True      False
# 597  q27  GAGGAGT      14273   True      False
# 598  q19  CCGCCTG       9789   True      False
# 599  q24  CCAGTTG       4173   True      False
# 600  q25  ACAATGA       3404   True      False
# 601  q27  CGCTTTG       1493   True      False
# 602  q24  ATTCGCT       1359   True      False
# 603  q19  CGCTTTG       1261   True      False
# 604  q26  GAGGAGT        990   True      False
# 605  q26  CCGCCTG        865   True      False
# 606  q24  CGCTTTG        864   True      False
# 607  q27  CCGCCTG        761   True      False
# 608  q19  GAGGAGT        726   True      False
# 609  q24  GAGGAGT        573   True      False
# 610  q25  CGCTTTG        556   True      False
# 611  q24  CCGCCTG        437   True      False
# 612  q27  GCGGAGT        409   True      False
# 613  q26  CCAGTTG        400   True      False
# 614  q25  GAGGAGT        383   True      False
# 615  q27  CCAGTTG        382   True      False
# 616  q27  ACAATGA        316   True      False
# 617  q19  CCAGTTG        300   True      False
# 618  q25  CCGCCTG        295   True      False
# 619  q26  ACAATGA        278   True      False
# 620  q19  ACAATGA        205   True      False
# 621  q24  ACAATGA        191   True      False
# 622  q24  CCCGTTG        148   True      False
# 623  q25  CCAGTTG        133   True      False
# 624  q27  ATTCGCT        132   True      False
# 625  q25  CCAATGA        112   True      False
# 626  q26  ATTCGCT        101   True      False
# 627  q25  ACCATGA         95   True      False
# 628  q19  ATTCGCT         93   True      False
# new 1493
#     qtag  barcode  mcountsPF passed is_padding
# 596  q26  CGCTTTG      19390   True      False
# 597  q27  GAGGAGT      14273   True      False
# 598  q19  CCGCCTG       9789   True      False
# 599  q24  CCAGTTG       4173   True      False
# 600  q25  ACAATGA       3404   True      False
# 601  q27  CGCTTTG       1493   True      False
#
# 19 33
# old 1493
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGCTTTG      19390   True      False
# 1  q27  GAGGAGT      14273   True      False
# 2  q19  CCGCCTG       9789   True      False
# 3  q24  CCAGTTG       4173   True      False
# 4  q25  ACAATGA       3404   True      False
# 5  q27  CGCTTTG       1493  False       True
# new 1493
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGCTTTG      19390   True      False
# 1  q27  GAGGAGT      14273   True      False
# 2  q19  CCGCCTG       9789   True      False
# 3  q24  CCAGTTG       4173   True      False
# 4  q25  ACAATGA       3404   True      False
# 5  q27  CGCTTTG       1493  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGCTTTG      19390   True      False
# 1  q27  GAGGAGT      14273   True      False
# 2  q19  CCGCCTG       9789   True      False
# 3  q24  CCAGTTG       4173   True      False
# 4  q25  ACAATGA       3404   True      False
# FINAL 5
# Thresholded.
#
# -------------
# Sample 19 of 27 (26):
# 20 24
# old -1
#    qtag  barcode  mcountsPF passed is_padding
# 38  q26  CGTAAAC      19019   True      False
# 39  q19  CTGGCGT       9703   True      False
# 40  q27  GCGGTAG       6717   True      False
# 41  q24  GCTTTAG       3560   True      False
# 42  q19  CGTAAAC       1385   True      False
# 43  q27  CGTAAAC       1191   True      False
# 44  q25  CCCGTCT       1080   True      False
# 45  q26  CTGGCGT        992   True      False
# 46  q24  CGTAAAC        837   True      False
# 47  q27  CTGGCGT        655   True      False
# 48  q26  GCGGTAG        613   True      False
# 49  q19  GCGGTAG        539   True      False
# 50  q24  CTGGCGT        459   True      False
# 51  q26  GCTTTAG        338   True      False
# 52  q24  GCGGTAG        336   True      False
# 53  q27  GCTTTAG        264   True      False
# 54  q25  CGTAAAC        250   True      False
# 55  q19  GCTTTAG        232   True      False
# 56  q25  CTGGCGT        141   True      False
# 57  q26  CCCGTCT        121   True      False
# 58  q19  CCCGTCT         96   True      False
# 59  q27  CCCGTCT         72   True      False
# 60  q25  GCGGTAG         67   True      False
# 61  q24  CCCGTCT         53   True      False
# new 9703
#    qtag  barcode  mcountsPF passed is_padding
# 38  q26  CGTAAAC      19019   True      False
# 39  q19  CTGGCGT       9703   True      False
#
# 19 24
# old 9703
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGTAAAC      19019   True      False
# 1  q19  CTGGCGT       9703   True      False
# new 9703
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGTAAAC      19019   True      False
# 1  q19  CTGGCGT       9703   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q26  CGTAAAC      19019   True      False
# 1  q19  CTGGCGT       9703   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 20 of 27 (27):
# -------------
# Sample 21 of 27 (3):
# -------------
# Sample 22 of 27 (4):
# 20 3
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 255  q24  GCTTTAG      89143   True      False
# 256  q24  GCTTTAT        161   True      False
# 257  q24  GCTTCAG         54   True      False
# new 161
#     qtag  barcode  mcountsPF passed is_padding
# 255  q24  GCTTTAG      89143   True      False
# 256  q24  GCTTTAT        161   True      False
#
# 19 3
# old 161
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCTTTAG      89143   True      False
# 1  q24  GCTTTAT        161  False       True
# new 161
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCTTTAG      89143   True      False
# 1  q24  GCTTTAT        161  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCTTTAG      89143   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 23 of 27 (5):
# 20 2
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 286  q27  CGCATAG      71214   True      False
# 287  q27  CGCATAT        131   True      False
# new 131
#     qtag  barcode  mcountsPF passed is_padding
# 286  q27  CGCATAG      71214   True      False
# 287  q27  CGCATAT        131   True      False
#
# 19 2
# old 131
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  CGCATAG      71214   True      False
# 1  q27  CGCATAT        131  False       True
# new 131
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  CGCATAG      71214   True      False
# 1  q27  CGCATAT        131  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  CGCATAG      71214   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 24 of 27 (6):
# -------------
# Sample 25 of 27 (7):
# 20 8
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 179  q19  GGGCGGC      43283   True      False
# 180  q24  CAGAAGT      33257   True      False
# 181  q24  GGGCGGC       6222   True      False
# 182  q19  CAGAAGT       4281   True      False
# 183  q24  CCGAAGT       1184   True      False
# 184  q19  CCGAAGT        155   True      False
# 185  q19  GGGCGAC        116   True      False
# 186  q19  GGGCAGC         58   True      False
# new 6222
#     qtag  barcode  mcountsPF passed is_padding
# 179  q19  GGGCGGC      43283   True      False
# 180  q24  CAGAAGT      33257   True      False
# 181  q24  GGGCGGC       6222   True      False
#
# 19 8
# old 6222
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      43283   True      False
# 1  q24  CAGAAGT      33257   True      False
# 2  q24  GGGCGGC       6222  False       True
# new 6222
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      43283   True      False
# 1  q24  CAGAAGT      33257   True      False
# 2  q24  GGGCGGC       6222  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGGCGGC      43283   True      False
# 1  q24  CAGAAGT      33257   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 26 of 27 (8):
# 20 7
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 315  q25  GGAGCCA      36053   True      False
# 316  q26  CGCTTTG      26183   True      False
# 317  q26  GGAGCCA       4198   True      False
# 318  q25  CGCTTTG       3923   True      False
# 319  q25  GGCGCCA       1013   True      False
# 320  q26  GGCGCCA        112   True      False
# 321  q25  GGAACCA        102   True      False
# new 4198
#     qtag  barcode  mcountsPF passed is_padding
# 315  q25  GGAGCCA      36053   True      False
# 316  q26  CGCTTTG      26183   True      False
# 317  q26  GGAGCCA       4198   True      False
#
# 19 7
# old 4198
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  GGAGCCA      36053   True      False
# 1  q26  CGCTTTG      26183   True      False
# 2  q26  GGAGCCA       4198  False       True
# new 4198
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  GGAGCCA      36053   True      False
# 1  q26  CGCTTTG      26183   True      False
# 2  q26  GGAGCCA       4198  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  GGAGCCA      36053   True      False
# 1  q26  CGCTTTG      26183   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 27 of 27 (9):
# 20 7
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 384  q27  GAGGAGT      49738   True      False
# 385  q19  CCGCCTG      19645   True      False
# 386  q19  GAGGAGT       3911   True      False
# 387  q27  CCGCCTG       3075   True      False
# 388  q27  GCGGAGT       1611   True      False
# 389  q19  GCGGAGT        106   True      False
# 390  q27  GAGAAGT         52   True      False
# new 106
#     qtag  barcode  mcountsPF passed is_padding
# 384  q27  GAGGAGT      49738   True      False
# 385  q19  CCGCCTG      19645   True      False
# 386  q19  GAGGAGT       3911   True      False
# 387  q27  CCGCCTG       3075   True      False
# 388  q27  GCGGAGT       1611   True      False
# 389  q19  GCGGAGT        106   True      False
#
# 19 7
# old 106
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GAGGAGT      49738   True      False
# 1  q19  CCGCCTG      19645   True      False
# 2  q19  GAGGAGT       3911  False       True
# 3  q27  CCGCCTG       3075  False      False
# 4  q27  GCGGAGT       1611  False      False
# 5  q19  GCGGAGT        106  False      False
# new 19645
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GAGGAGT      49738   True      False
# 1  q19  CCGCCTG      19645   True      False
#
# 18 7
# old 19645
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GAGGAGT      49738   True      False
# 1  q19  CCGCCTG      19645   True      False
# new 19645
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GAGGAGT      49738   True      False
# 1  q19  CCGCCTG      19645   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q27  GAGGAGT      49738   True      False
# 1  q19  CCGCCTG      19645   True      False
# FINAL 2
# Thresholded.

# %%
fconcat = pd.concat([d[1] for d in filtered if d[0][:2]!="VL" ])
merged = fconcat.merge(passeddf, 
              on=['idx','qtag','barcode','mcountsPF','readsPF'], 
                       how='outer')
merged.drop(['percent_mcountsPF_x','is_padding'],axis=1, inplace=True)
merged.rename(columns={'percent_mcountsPF_y':"percent_mcountsPF"}, inplace=True)
merged = merged.fillna(value={'passed':False,'qtag_error':False,'barcode_error':False,
                    'percent_mcountsPF':0.})

# %%
passeddf.loc[passeddf['passed']==True]
# Out:
#      idx qtag  barcode  mcountsPF  readsPF  percent_mcountsPF passed  \
# 0      1  q19  GGGCGGC      79618   102145         100.000000   True
# 30    10  q24  CCAGTTG      41816    47259          72.700720   True
# 31    10  q24  ATTCGCT      15702    16376          27.299280   True
# 119   11  q26  CGTAAAC      81232   104913          91.154127   True
# 120   11  q27  GCGGTAG       7883     8044           8.845873   True
# 171   12  q19  CTGGCGT      78535   100514          95.486765   True
# 172   12  q24  GCTTTAG       3712     3739           4.513235   True
# 214   13  q25  CCCGTCT      69129    85469          99.711520   True
# 215   13  q26  CATATAT        200      201           0.288480   True
# 263   14  q19  GGGCGGC      21111    22459          40.854201   True
# 264   14  q27  CGCATAG      16209    16977          31.367806   True
# 265   14  q24  CAGAAGT      14354    14904          27.777993   True
# 353   15  q25  GGAGCCA      17705    18607          47.230966   True
# 354   15  q27  GAGGAGT      10116    10409          26.986075   True
# 355   15  q26  CGCTTTG       9665     9944          25.782959   True
# 444   16  q19  CCGCCTG      35493    39366          83.634950   True
# 445   16  q25  ACAATGA       6945     7090          16.365050   True
# 538   17  q19  CTGGCGT       5933     6028          35.620797   True
# 539   17  q24  GCTTTAG       5218     5305          31.328050   True
# 540   17  q26  CGTAAAC       2852     2879          17.122959   True
# 541   17  q27  GCGGTAG       2653     2678          15.928194   True
# 607   18  q19  GGGCGGC      14184    14750          33.686410   True
# 608   18  q24  CAGAAGT      11074    11405          26.300290   True
# 609   18  q27  CGCATAG      10387    10676          24.668693   True
# 610   18  q26  CATATAT       6461     6583          15.344606   True
# 754   19  q19  CCGCCTG       7671     7840          26.459023   True
# 755   19  q26  CGCTTTG       6449     6564          22.244067   True
# 756   19  q24  CCAGTTG       5745     5832          19.815811   True
# 757   19  q27  GAGGAGT       5450     5544          18.798289   True
# 758   19  q25  ACAATGA       3677     3721          12.682809   True
# ...   ..  ...      ...        ...      ...                ...    ...
# 1145  22  q26  CGCTTTG      40450    45571          90.251902   True
# 1146  22  q25  ACAATGA       4369     4421           9.748098   True
# 1296  23  q27  GCGGTAG      37849    42369          90.932898   True
# 1297  23  q19  CTGGCGT       3774     3831           9.067102   True
# 1407  24  q19  GGGCGGC      12299    12736          27.973253   True
# 1408  24  q27  CGCATAG      11083    11455          25.207542   True
# 1409  24  q26  CATATAT       7881     8031          17.924807   True
# 1410  24  q24  CAGAAGT       7192     7347          16.357723   True
# 1411  24  q25  GGAGCCA       5512     5603          12.536675   True
# 1549  25  q26  CGCTTTG      19390    20515          37.998001   True
# 1550  25  q27  GAGGAGT      14273    14838          27.970370   True
# 1551  25  q19  CCGCCTG       9789    10048          19.183210   True
# 1552  25  q24  CCAGTTG       4173     4222           8.177703   True
# 1553  25  q25  ACAATGA       3404     3448           6.670717   True
# 1725  26  q26  CGTAAAC      19019    20018          66.217534   True
# 1726  26  q19  CTGGCGT       9703     9960          33.782466   True
# 1827  27  q25  ACAATGA          1        1          50.000000   True
# 1828  27  q26  CGTAAAC          1        1          50.000000   True
# 1829   3  q24  GCTTTAG         40       40          93.023256   True
# 1830   3  q25  GGAGCCA          3        3           6.976744   True
# 1836   4  q24  GCTTTAG      89143   118591         100.000000   True
# 1867   5  q27  CGCATAG      71214    88842         100.000000   True
# 1896   6  q25  GGAGCCA          5        5          71.428571   True
# 1897   6  q27  CGCATAG          2        2          28.571429   True
# 1905   7  q19  GGGCGGC      43283    49084          56.549517   True
# 1906   7  q24  CAGAAGT      33257    36561          43.450483   True
# 1981   8  q25  GGAGCCA      36053    40086          57.929494   True
# 1982   8  q26  CGCTTTG      26183    28094          42.070506   True
# 2050   9  q27  GAGGAGT      49738    57584          71.686148   True
# 2051   9  q19  CCGCCTG      19645    20767          28.313852   True
#
#      qtag_error barcode_error is_padding
# 0         False         False      False
# 30        False         False      False
# 31        False         False      False
# 119       False         False      False
# 120       False         False      False
# 171       False         False      False
# 172       False         False      False
# 214       False         False      False
# 215       False         False      False
# 263       False         False      False
# 264       False         False      False
# 265       False         False      False
# 353       False         False      False
# 354       False         False      False
# 355       False         False      False
# 444       False         False      False
# 445       False         False      False
# 538       False         False      False
# 539       False         False      False
# 540       False         False      False
# 541       False         False      False
# 607       False         False      False
# 608       False         False      False
# 609       False         False      False
# 610       False         False      False
# 754       False         False      False
# 755       False         False      False
# 756       False         False      False
# 757       False         False      False
# 758       False         False      False
# ...         ...           ...        ...
# 1145      False         False      False
# 1146      False         False      False
# 1296      False         False      False
# 1297      False         False      False
# 1407      False         False      False
# 1408      False         False      False
# 1409      False         False      False
# 1410      False         False      False
# 1411      False         False      False
# 1549      False         False      False
# 1550      False         False      False
# 1551      False         False      False
# 1552      False         False      False
# 1553      False         False      False
# 1725      False         False      False
# 1726      False         False      False
# 1827      False         False      False
# 1828      False         False      False
# 1829      False         False      False
# 1830      False         False      False
# 1836      False         False      False
# 1867      False         False      False
# 1896      False         False      False
# 1897      False         False      False
# 1905      False         False      False
# 1906      False         False      False
# 1981      False         False      False
# 1982      False         False      False
# 2050      False         False      False
# 2051      False         False      False
#
# [71 rows x 10 columns]

# %%
merged.loc[(merged['passed']==True)|(merged.mcountsPF > 300)]
# Out:
#          idx qtag  barcode  mcountsPF  readsPF  percent_mcountsPF passed  \
# 0          1  q25  TTGCTTC      21979    23011         100.000000   True
# 37    180-10  q19  TTGTGGC       3516     4600          80.018207   True
# 38    180-10  q24  CGGTGTG        878     1104          19.981793   True
# 118   180-12  q19  TTGTGGC       1453     1616          67.268519   True
# 119   180-12  q24  CGGTGTG        707      746          32.731481   True
# 165        2  q24  GGTTGAT      61172    68931         100.000000   True
# 223       20  q19  GATCCAT     189720   465296         100.000000   True
# 363       21  q23  GTTTCTG      13552    13456         100.000000   True
# 390       22  q23  GTTTCTG     166365   339984         100.000000   True
# 391       22  q23  GTTTCTA        364      316           0.000000  False
# 392       22  q23  GTTTCCG        360      307           0.000000  False
# 481       23  q24  GCGTCTC      15262    15289         100.000000   True
# 515       24  q24  GGGATAT      21939    22133         100.000000   True
# 559       25  q19  TGTATGG      42568    48312         100.000000   True
# 610       26  q19  TGTATGG      21539    22583         100.000000   True
# 641       27  q19  ATCCTTT      24880    26404         100.000000   True
# 690       28  q23  GTTTCTG      28217    29812          45.766698   True
# 691       28  q19  TGTATGG      21353    21946          34.633600   True
# 692       28  q24  GGGATAT      12084    11757          19.599702   True
# 693       28  q19  GTTTCTG       1458     1372           0.000000  False
# 694       28  q23  TGTATGG       1315     1225           0.000000  False
# 695       28  q24  GTTTCTG       1018      917           0.000000  False
# 696       28  q24  TGTATGG        791      716           0.000000  False
# 697       28  q23  GGGATAT        682      604           0.000000  False
# 698       28  q19  GGGATAT        601      533           0.000000  False
# 815       29  q19  GGTGGGC      68425    78713         100.000000   True
# 816       29  q19  GGTGTGC        584       32           0.000000  False
# 817       29  q19  GGTTGGC        456       49           0.000000  False
# 895        3  q24  GAGTGTG      14220    13854          59.013944   True
# 896        3  q23  AGTTATT       9876     9396          40.986056   True
# 897        3  q23  GAGTGTG        614      560           0.000000  False
# 898        3  q24  AGTTATT        607      532           0.000000  False
# 950        4  q23  GTTTCTG      28058    30154         100.000000   True
# 980        5  q19  GAACTTC     103126   149848         100.000000   True
# 1046       6  q23  GTTTCTG      23803    24691         100.000000   True
# 1078       7  q23  ATTGTGT      28025    28960         100.000000   True
#
#      qtag_error barcode_error
# 0         False         False
# 37        False         False
# 38        False         False
# 118       False         False
# 119       False         False
# 165       False         False
# 223       False         False
# 363       False         False
# 390       False         False
# 391       False          True
# 392       False         False
# 481       False         False
# 515       False         False
# 559       False         False
# 610       False         False
# 641       False         False
# 690       False         False
# 691       False         False
# 692       False         False
# 693        True         False
# 694       False         False
# 695       False         False
# 696       False         False
# 697       False         False
# 698       False         False
# 815       False         False
# 816       False         False
# 817       False         False
# 895       False         False
# 896       False         False
# 897        True         False
# 898       False         False
# 950       False         False
# 980       False         False
# 1046      False         False
# 1078      False         False

# %%
passeddf.to_csv("%s/passed-%s.csv"%(OUTPUT_DIRECTORY,EXPERIMENT))

# %% [raw]
# # plots scatter
# for idx, group in filtered_concat.groupby('idx'):
#     g = group.sort_values(by='mcounts_PF',ascending=False)
#     counts = g.mcounts_PF.values
#     itypes = g.qb_type.values
#
#     f, ax = plt.subplots(1)
#     # 0 == passed
#     # 1 == fail (not mismatch)
#     # 2 == fail (mismatch)
#     for i in [0,1,2]:
#         x = []
#         y = []
#         j = 0
#         typecount = 0
#         while j < len(counts):
#             if itypes[j]==i and counts[j]>1:
#                 x.append(j)
#                 y.append(counts[j])
#                 typecount += 1
#             j+=1
#         label = "%s: %d"%(labels[i],typecount)
#         alpha = 1
#         ax.bar(x, y, fill=ctypes[i], alpha=alpha, label=label,
#                   lw=0)
#         ax.scatter(x, y, color=ctypes[i], alpha=alpha, label=label,
#                   marker='.', lw=2)
#
#     thresh =max(np.where(itypes==0)[0])
#     ax.plot([thresh,thresh],[1,max(counts)], color = ctypes[0], label='%d QB > threshold'%len(np.where(itypes==0)[0]))
#     ax.set_yscale('log')
#     ax.set_xlim(0)
#     ax.legend()
#     ax.set_title(idx)

# %%
all_threshold_logs
# Out:
# {'1': [2, 2, 1],
#  '10': [2, 2, 2],
#  '11': [2, 2, 2],
#  '12': [2, 2, 2],
#  '13': [2, 2, 2],
#  '14': [4, 4, 3],
#  '15': [4, 4, 3],
#  '16': [2, 2, 2],
#  '17': [5, 5, 4],
#  '18': [28, 4, 4, 4],
#  '19': [5, 5, 5],
#  '2': [2, 2, 1],
#  '20': [6, 6, 5],
#  '21': [6, 6, 5],
#  '22': [2, 2, 2],
#  '23': [2, 2, 2],
#  '24': [6, 6, 5],
#  '25': [6, 6, 5],
#  '26': [2, 2, 2],
#  '4': [2, 2, 1],
#  '5': [2, 2, 1],
#  '7': [3, 3, 2],
#  '8': [3, 3, 2],
#  '9': [6, 2, 2, 2]}

# %%
passed_counts = passeddf.loc[passeddf['passed']==True].groupby('idx').apply(len)

# %%
for idx, group in passeddf.groupby('idx'):
    passed_g = group.loc[group['passed']==True,'mcountsPF']
    thresh_val = passed_g.values[-1]
    over_thresh = len(group.loc[group['mcountsPF']>=thresh_val])
    print idx, thresh_val, len(group.loc[group['passed']==True,'mcountsPF']), over_thresh
# Out:
# 1 79618 1 1
# 10 15702 2 2
# 11 7883 2 2
# 12 3712 2 2
# 13 200 2 2
# 14 14354 3 3
# 15 9665 3 3
# 16 6945 2 2
# 17 2653 4 4
# 18 6461 4 4
# 19 3677 5 5
# 2 75662 1 1
# 20 1072 5 5
# 21 5374 5 5
# 22 4369 2 2
# 23 3774 2 2
# 24 5512 5 5
# 25 3404 5 5
# 26 9703 2 2
# 4 89143 1 1
# 5 71214 1 1
# 7 33257 2 2
# 8 26183 2 2
# 9 19645 2 2

# %% [markdown]
# ## GRAPHING

# %%
itypes = {
    (True,False,False):'passed', #passed
    (False,True,False):'qtag mismatch', #qtag error
    (False,False,True):'barcode oneoff', #barcode error
    (False,False,False):'other error' #not one-off
}

for itype in itypes:
    keys = ['passed','qtag_error','barcode_error']
    ca = [(merged[k]==v) for k,v in zip(keys,itype)]
    cond = ca[0]&ca[1]&ca[2]
    merged.loc[(cond),'itype'] = itypes[itype]
    
ctypes = {
    'passed':'#11BF08',
    'barcode oneoff': '#DE092B',
    'qtag mismatch':'#EBA709',
    'other error':'#2A52D5'
}
itype_order = [
    'passed',
    'other error',
    'barcode oneoff',
    'qtag mismatch'
]

# %%
# plots scatter
plottype = 'bar'
mcounts=MCOUNTS
counter = 0
for idx, group in merged.groupby('idx'):
#     if idx[:2]=='NH':
    if idx in all_threshold_logs:
        gslice = group.sort_values(by=mcounts,ascending=False)
        gslice = gslice.loc[gslice[mcounts]>1]
        counts = gslice[mcounts].values
        itypes = gslice.itype.values
        it_present= np.unique(itypes)
        
        f, ax = plt.subplots(1)
        for itype in itype_order:
            if itype in it_present:
                x = np.where(itypes==itype)[0]
                y = counts[x]
                label = "%s: %d"%(itype,len(x))
                color = ctypes[itype]
                alpha = 0.5 if itype in ['passed','other error'] else 1
                edgecolor=color
                lw = 1.5
                s = 250 if itype in ['barcode oneoff','qtag mismatch'] else 8
                marker = "|" if itype in ['barcode oneoff','qtag mismatch'] else "o"
                    
                if plottype == 'scatter':
                    ax.scatter(x+1, y, color=color, edgecolors=edgecolor,
                            alpha=alpha, label=label, 
                            marker=marker, lw=lw, s=s)
                    
                else:
                    ax.bar(x, y, color=color, alpha=alpha, 
                           label=label, lw=0, width=1 )
        
        thresh_values = all_threshold_logs[idx]
        thresh_line_fmts = 1
        for tline in range(1,len(thresh_values)):
            thresh_line = thresh_values[tline]
    #             thresh_line =np.max(np.where(itypes=='passed')[0])+1

            if thresh_line != thresh_values[tline-1]:
#                 alpha = thresh_line_fmts[len(thresh_values)-tline-1]
                alpha = thresh_line_fmts - 0.5*(tline-1)
                ax.plot([thresh_line,thresh_line],[1,max(counts)], 
                        color = 'black', alpha = 1, ls = '--',
                        label='%d QB > threshold iter %d'%(thresh_line, tline+1))
        ax.set_yscale('log')
        ax.set_xlim(0)
        ax.legend()
        ax.set_title(idx)
#         break
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 202
# C:\Users\vwl698\Anaconda2\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [raw]
# #####  Color Palette by Paletton.com
# #####  Palette URL: http://paletton.com/#uid=c3P112O5x0kuKtzjHyVsYK-v+n-Cvj1
#
# 1.  BLUE    other error
# 2.  GREEN   passed
# 3.  RED     barcode oneoff
# 4.  YELLOW  qtag mismatch
#
# *** Primary color:
#
#    shade 0 = #18379F = rgb( 24, 55,159) = rgba( 24, 55,159,1) = rgb0(0.094,0.216,0.624)
#    shade 1 = #5269B4 = rgb( 82,105,180) = rgba( 82,105,180,1) = rgb0(0.322,0.412,0.706)
#    >>>>shade 2 = #2A52D5 = rgb( 42, 82,213) = rgba( 42, 82,213,1) = rgb0(0.165,0.322,0.835)<<<<
#    shade 3 = #0F297F = rgb( 15, 41,127) = rgba( 15, 41,127,1) = rgb0(0.059,0.161,0.498)
#    shade 4 = #091F67 = rgb(  9, 31,103) = rgba(  9, 31,103,1) = rgb0(0.035,0.122,0.404)
#
# *** Secondary color (1):
#
#    shade 0 = #11BF08 = rgb( 17,191,  8) = rgba( 17,191,  8,1) = rgb0(0.067,0.749,0.031)
#    shade 1 = #58D351 = rgb( 88,211, 81) = rgba( 88,211, 81,1) = rgb0(0.345,0.827,0.318)
#    shade 2 = #20E616 = rgb( 32,230, 22) = rgba( 32,230, 22,1) = rgb0(0.125,0.902,0.086)
#    shade 3 = #089800 = rgb(  8,152,  0) = rgba(  8,152,  0,1) = rgb0(0.031,0.596,0)
#    shade 4 = #067B00 = rgb(  6,123,  0) = rgba(  6,123,  0,1) = rgb0(0.024,0.482,0)
#
# *** Secondary color (2):
#
#    shade 0 = #DE092B = rgb(222,  9, 43) = rgba(222,  9, 43,1) = rgb0(0.871,0.035,0.169)
#    shade 1 = #F25D75 = rgb(242, 93,117) = rgba(242, 93,117,1) = rgb0(0.949,0.365,0.459)
#    shade 2 = #F8183B = rgb(248, 24, 59) = rgba(248, 24, 59,1) = rgb0(0.973,0.094,0.231)
#    shade 3 = #B1001C = rgb(177,  0, 28) = rgba(177,  0, 28,1) = rgb0(0.694,0,0.11)
#    shade 4 = #8F0017 = rgb(143,  0, 23) = rgba(143,  0, 23,1) = rgb0(0.561,0,0.09)
#
# *** Complement color:
#
#    shade 0 = #EBA709 = rgb(235,167,  9) = rgba(235,167,  9,1) = rgb0(0.922,0.655,0.035)
#    shade 1 = #FFCF62 = rgb(255,207, 98) = rgba(255,207, 98,1) = rgb0(1,0.812,0.384)
#    shade 2 = #FFB918 = rgb(255,185, 24) = rgba(255,185, 24,1) = rgb0(1,0.725,0.094)
#    shade 3 = #BC8300 = rgb(188,131,  0) = rgba(188,131,  0,1) = rgb0(0.737,0.514,0)
#    shade 4 = #986900 = rgb(152,105,  0) = rgba(152,105,  0,1) = rgb0(0.596,0.412,0)
#
#
# #####  Generated by Paletton.com (c) 2002-2014
