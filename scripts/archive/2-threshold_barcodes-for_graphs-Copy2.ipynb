# %%
# %matplotlib inline


import pandas as pd
import numpy as np
import regex
import os, sys
import matplotlib.pyplot as plt

# %% [markdown]
# # USER INPUTS

# %%
"""Experiment name to prepend output files"""
EXPERIMENT = "18014_graphing-2"

"""Directory path to input data 
    (filtered; output from '1-read_fastq_id_features)
"""
# FILTERED_FILEPATH = "../output/filtered-sample-nh.csv"
FILTERED_FILEPATH = "../output/filtered-18014.csv"
# FILTERED_FILEPATH = '../../../2016-09-19-validation_graphs_redoes/data/filtered-ratios.csv'
"""Directory path to save output"""
OUTPUT_DIRECTORY = "../output"

"""Minimum number of reads as a baseline. Used to simplify data processing."""
MIN_READS = 100
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 212

# %% [markdown]
# # PRESETS AND SCRIPT

# %%
"""
# NEED TO FIGURE HOW TO RELOAD DEPENDENT FUNCTIONS
UPON VALUE CHANGES
Column names correspoinding to eponymous variables"""

SAMPLE = 'idx'
QTAG = 'qtag'
BARCODE = 'barcode'
READS = 'readsPF'
MCOUNTS = 'mcountsPF'
PERCENT_MCOUNTS = 'percent_%s'%MCOUNTS
GROUPBY = ['idx']# for older versions/ formats

# %%
def check_inputs():
    
    # modules
    assert pd
    assert np
    assert regex
    assert os
    assert sys
    
    # user experiment inputs 
    assert EXPERIMENT
    assert FILTERED_FILEPATH
    assert OUTPUT_DIRECTORY
    assert MIN_READS
    
    # user columns
    assert SAMPLE
    assert QTAG
    assert BARCODE
    assert READS
    assert MCOUNTS
    assert PERCENT_MCOUNTS
    assert GROUPBY

# %%
# 2016-11-04 updated to include filter delete bool feature
"""calculate_percent_molecs
    calculates percent of mcounts of barcodes.
    df: pd.DataFrame() 
    mcounts: str, optional, col to calculate percents, default MCOUNTS
    percent_mcounts: str, col to assign values to, default PERCENT_MCOUNTS
    filters: list, np.array, dict, columns and bool values to filter values
    
    Returns: 
        df with updated percent_mcounts values
"""
def calculate_percent_molecs(df, mcounts=MCOUNTS, percent_mcounts=PERCENT_MCOUNTS, filters=[]):
    """Updates percent molec counters for sample"""
    
    df.loc[:,percent_mcounts] = 0.
    if len(filters) > 0:
        var, val = filters[0]
        cond = (df[var]==val)
        i = 1
        while i < len(filters):
            var, val = filters[i]
            cond = cond & (df[var]==val)
            i+=1
    else:
        cond = ()
    total = df.loc[cond, mcounts].values.sum() / 100.
    df.loc[cond,percent_mcounts] = df.apply(lambda x: x[mcounts]/total, axis=1)
    df.sort_values(by=[percent_mcounts,mcounts, BARCODE], 
                   ascending=[0,0,1], inplace=True)
    return df

# %%
def load_data(filtered_file, sample=SAMPLE, qtag=QTAG, 
              barcode=BARCODE, mcounts=MCOUNTS, reads=READS):
    """Loads filtered lib-ID-barcode data csv to dict of samples"""
    columns = [sample, qtag, barcode, mcounts, reads]
    # loads excel file (all tabs)
    
    csv = pd.read_csv(filtered_file)
    # filter out null barcodes just in case (if custom user input)
    csv = csv.loc[(csv[qtag]!='None') & (csv[barcode]!='None')]
    csv = csv[columns]
    csv[sample] = csv[sample].apply(lambda x: str(x))
    # get percent molecs per sample, store as output dict entry 
    groups = csv.groupby(sample)
    data = []
    for i, group in csv.groupby(sample):
        data.append((i,calculate_percent_molecs(group)))
    return data

# %%
def check_data(d, sample=SAMPLE, mcounts=MCOUNTS, reads=READS):
    """Check data for proper format, input values, and 
    converts into list-like object if necessary

    d(list, np.array ,dict, or pd.DataFrame): input data
    
    Returns: data set as a list-like object, wherein
        each item is a pair containing sample name (str) and 
        sample data (pd.DataFrame), in that order.
    """
    data_arr = []
    # wrangle data to list of list-like pairs, as "[idx, df]"
    if type(d) in [np.array, list] :
        data_arr = d
    elif type(d) == dict:
        data_arr = d.items()
    elif type(d) == pd.DataFrame :
        data_arr = [(s,df) for s,df in d.groupby(sample)]
    else:
        print "Input data is not in correct format. Please provide \
        list-like, dict, or pd.DataFrame object."
    
    # check input has correct values
    try:
        for a in data_arr:
            assert len(a) == 2, "incorrect item length"
            s, df = a
            assert type(s) == str, 'sample name is not string type'
            assert type(df) == pd.DataFrame, "incorrect value type: must be pd.DataFrame"
            assert sample in df.columns, "%s not in dataframe"%sample
            assert mcounts in df.columns, "%s not in dataframe"%mcounts
            assert reads in df.columns, "%s not in dataframe"%reads
    # if no 
    except IndexError as e:
        print "Item number of values is not 2.\n"
        print "IndexError. ",e.message
        print a
    except ValueError as e:
        print "Sample name could not be converted to float: %s\n"% type(item[i])
        print "ValueError. ",e.message
        print a
    except AssertionError as e:
        print "Assertion failed:"
        print e.message
        print a
    
    return data_arr

# %%
"""OLD THRESHOLD"""

def threshold(group, reps_remaining, thresh_mcounts,threshold_log,
             mcounts=MCOUNTS):
    """Thresholds barcodes of a given sample

        group(pd.DataFrame): df containing library-ID-barcodes, 
            mcountsPF and percent_mcountsPF
        reps_remaining(int): reps remaining from max number 
            input from user 
        thresh_val(float or int): initial threshold value (percent_mcountPF)
            provided from previous recursion or user input
        thresh_i(int): initial position of threshold value in 
            percent_mcountsPF list, ranging 0,len(group)

        Returns: 
            None, if thresholding fails;
            passed(pd.DataFrame), if thresholding successful; or
            self, otherwise, with updated threshold values and 
                group df.
    """
#     print "\nSTART", len(group)
    # max out reps
    if reps_remaining <= 0:
        print 'Maxed out reps. Skipping sample.'
    # no barcodes passed threshold 
    elif len(group) == 0:
        print "No barcodes passed threshold. Skipping sample."
    else:
        # calculate new threshold 
        group.sort_values(by=mcounts, ascending=False, inplace=True)
        mcount_vals = group.loc[(group['passed']==True)|(group['is_padding']==True)][mcounts].values
#         mcount_vals = thresh_group[mcounts].values
#         mcount_vals = mcount_vals + [1] if thresh_mcounts < 0 or len(thresh_group) <= 3 else mcount_vals
#         print "G", group
#         print "THRG", thresh_group
#         print"MCV",  mcount_vals
#         print "else", reps_remaining, len(group), len(mcount_vals)
        new_thresh_mcounts = calculate_threshold(mcount_vals)
#         print "after", reps_remaining, len(group), thresh_mcounts, new_thresh_mcounts
        
        threshold_log.append(len(group.loc[(group[mcounts]>=new_thresh_mcounts)&(group['passed']==True)]))
        print '\n',reps_remaining, len(group)
        print 'old', thresh_mcounts
        print group.loc[(group[mcounts]>=thresh_mcounts)&(group[mcounts]>1)][['qtag','barcode','mcountsPF','passed','is_padding']]
        print 'new', new_thresh_mcounts
        print group.loc[group[mcounts]>=new_thresh_mcounts][['qtag','barcode','mcountsPF','passed','is_padding']]
#         print len(thresh_group.loc[thresh_group[mcounts]>new_thresh_mcounts])
        
#         print len(group), len(thresh_group)
        # if reached steady state
        if new_thresh_mcounts == thresh_mcounts:
#             re_thresholded_v = calculate_threshold(group.loc[group['passed']==True][mcounts].values)
#             print thresh_mcounts, re_thresholded_v
#             passed = eliminate_oneoffs(group, re_thresholded_v, pad=False)
#             passed = eliminate_oneoffs(group, new_thresh_mcounts, pad=False)
#             print len(group.loc[group['passed']==True]), len(passed.loc[passed['passed']==True])
            group['passed'] = group.apply(lambda x:
                            True if x['passed']==True and
                            x['is_padding']==False and
                            x[mcounts]>=new_thresh_mcounts else False, axis=1)
            passed_val = group.loc[group['passed']==True,mcounts].min()
            threshold_log.append(len(group.loc[group[mcounts]>=passed_val]))

            print 'final'
            print group.loc[group['passed']==True][['qtag','barcode','mcountsPF','passed','is_padding']]
#             group.loc[(group['passed']==True)
#                               &(group['is_padding']==False)
#                               &(group[mcounts]>=thresh_mcounts)]
            
            group = calculate_percent_molecs(group,filters=[['passed',True],['is_padding',False]])
#             passed = calculate_percent_molecs(group, 
#                         filters=[['passed',True],['is_padding',False]])
            group.reset_index(inplace=True,drop=True)
            print "FINAL", len(group.loc[group['passed']==True])
            sys.stdout.write('Thresholded.\n')
            return group, threshold_log
        # recursively clean and re-threshold
        else:
#             print reps_remaining
#             print len(group), thresh_mcounts, new_thresh_mcounts
            # clean up group by eliminating one-offs
            cleaned = eliminate_oneoffs(group,new_thresh_mcounts)
            cleaned.reset_index(inplace=True,drop=True)
#             print reps_remaining, len(cleaned.loc[cleaned['passed']==True])
            # recurse with cleaned df and new threshold values
            return threshold(cleaned, reps_remaining-1, new_thresh_mcounts, threshold_log,
                             mcounts=mcounts)
        
    # if thresholding failed, return None
    sys.stdout.write('Skipped.\n')
    return pd.DataFrame()

# %%
# STEP 2: CALCULATE THRESHOLD VALUE via. CONCAVITY


def calculate_threshold(y, by='passed', mcounts=MCOUNTS):
    """Calculates threshold of series with modified concavity approach

        y(np.array or list): list or list-like object of 
            values as floats or ints

        Returns index of inflection point in array, 
            i.e. threshold position.
    """
    def rolling_window(arr):
        """Constructs list of overlapping subarray ranges of size 2"""
        shape = arr.shape[:-1] + (arr.shape[-1]-1, 2)
        strides = arr.strides + (arr.strides[-1],)
        windows = np.lib.stride_tricks.as_strided(arr, 
                              shape=shape, strides=strides)
        return windows
    def first_d_gen(windows):
        """Generates first derivative of windows as relative difference"""
        for w in windows:
            # amended 2016-10-12: normalize by y midpoint instead of second point to 
            # better represent the count magnitude of segment
            yield float(w[1]-w[0])/(w[0]+w[1])*2
    def second_d_gen(windows):
        """Generates second derivative of windows"""
        for w in windows:
            yield w[1]-w[0]       
            
    if type(y) in [np.ndarray, list]:
        x_temp = np.array([])
        y_temp = np.array(y)
    else:
        y = pd.DataFrame(y)
        sortby, cond = [mcounts], (y[mcounts]>0)
        if by in y.columns:
            sortby, cond = ['passed']+sortby, cond&(y['passed']==True) 
        passed = y.loc[cond].sort_values(by=sortby,ascending=False)[mcounts]
        x_temp = passed.index.values
        y_temp = passed.values
    
    
    y_temp = np.sort(np.array(y_temp))[::-1]
    # left and right padding to cover all array vals in derivations
    suffix = [] if len(y_temp) > 2 else [1]
#     suffix=[]
#     suffix = [] if len(y_temp) > 1 else [y_temp[0]]
#     suffix = [y_temp[len(y_temp)-1]/(y_temp[0]+y_temp[1])*2]
#     if len(y_temp) < 2:
#         suffix = [y_temp[len(y_temp)-1]/2]
#     else:
#         suffix =  [y_temp[len(y_temp)-1] -
#                    (y_temp[len(y_temp)-2]-y_temp[len(y_temp)-1])]
    
    yarray = np.concatenate([ [y_temp[0]], y_temp, suffix])
    # calculates first derivative
    first_windows = rolling_window(yarray)
    first_derivs = np.fromiter(first_d_gen(first_windows), np.float
                               , count=len(first_windows))
    # calculates second derivative
    second_windows = rolling_window(first_derivs)
    second_derivs = np.fromiter(second_d_gen(second_windows), np.float
                                , count=len(second_windows))
    # gets index or position value of inflection point (curves down ), adjust by adding 1
    # for second deriv
    thresh_i = min(np.argmin(second_derivs)+1, len(y_temp)-1)
    thresh_v = y_temp[thresh_i]
    
#     print "min", np.min(second_derivs), np.argmin(second_derivs)
#     print 'max', np.max(second_derivs), np.argmax(second_derivs)
    return thresh_v

# %%
def eliminate_oneoffs(g, thresh_val, pad=True,
                      qtag=QTAG, barcode=BARCODE, passed='passed',
                      barcode_error = 'barcode_error',
                      qtag_error = 'qtag_error',
                      mcounts=MCOUNTS):
    """Eliminate barcodes that are one position off from a more-abundant barcode
        group(pd.DataFrame): df containing qtag, barcode, and percent_mcounts columns
        thresh_val(float): threshold value to select high abundant barcodes
            to iterate through as 'major' ones
        pad(bool): if True, adds a right pad so last non-eliminated value 
            can be analyzed in by the threshold() function. Default True.
        qtag, barcode, percent_mcounts, mcounts (str): column names for the corresponding
            argument. Defaults are global vars QTAG, BARCODE, PERCENT_MCOUNTS, MCOUNTS.

        Returns: table of barcodes that passed elimination
        
        For regex package info, see https://pypi.python.org/pypi/regex/
    """
    g.sort_values(by=mcounts, ascending=False, inplace=True)
    g.loc[g[mcounts] < thresh_val, 'passed'] = False
    g.loc[:,'is_padding'] = False
    failed = []
#     print "elim", len(g), thresh_val, len(g.loc[g['passed']==True]), len( g.loc[(g['passed']==True)&(g[mcounts])>=thresh_val])
#     majors = filter_g.loc[(filter_g[mcounts])>thresh_val]
    i = 0
    # add capability to check other parameters, i.e. qtag
#     for maj_i, maj_r in g.loc[(g['passed']==True)&(g[mcounts])>=thresh_val].iterrows():
    for maj_i, maj_r in g.loc[g['passed']==True].iterrows():
        # if it has not yet been tested
        if g.loc[maj_i,'passed'] == True:
#             print 'passed maj', maj_r[mcounts]
#             minors = filter_g.loc[filter_g[mcounts]<maj_r[mcounts]]

            minors = g.loc[(g['passed']==True)&(g[mcounts]<maj_r[mcounts])]

            # for each 'minor' barcode aka. with fewer molecs, test if one-off from major
            for min_i, min_r in minors.iterrows():
                query = regex.search("(%s){s<=1}"% maj_r[barcode], min_r[barcode])
                if query:
                    g.loc[min_i,'passed'] = False
                    g.loc[min_i,'barcode_error'] += 1 if sum(query.fuzzy_counts)>0 else 0
                    g.loc[min_i,'qtag_error'] += 1 if min_r[qtag]!=maj_r[qtag] else 0
#                     if min_r[mcounts] < thresh_val:
                    failed.append([min_i, min_r[mcounts]])
                                          
            i+=1
                    
#     # if requested, adds a right pad  
#     # line added 2016-10-12: combine two conditions: ensure that 
#     # no null rows get added if all barcodes are accepted
#     g.loc[:,'passed'] = g.apply(lambda x: False if g.index in failed else x['passed'], axis=1)
#     print len(g), len(g.loc[g['passed']==False]), len(failed)
#     print "THR VAL",thresh_val
#     print g
#     print g['passed']==False
    if len(failed) > 0:
        failed.sort(key=lambda x: x[1])
        failed = failed[::-1]
    
#     if pad==True and len(failed) > 0:
    if pad==True and len(g) != len(g.loc[g['passed']==False]):
        pad_i = [f[0] for f in failed[:1]]
        pad_i = g.loc[(g['passed']==False),mcounts][:1].index.values
#         print "PADI", pad_i
        for pi in pad_i:
            g.loc[pi,'is_padding'] = True
#         print "PADI ADJ"
#         print g
    return g

# %%
def run_threshold(d, sample=SAMPLE, qtag=QTAG, barcode=BARCODE, 
                  mcounts=MCOUNTS, reads=READS, percent_mcounts=PERCENT_MCOUNTS,
                  min_reads=MIN_READS, min_mcount=50):
    """Run threshold algorithm for each sample in dataset

        d(np.array, list, dict, or pd.DataFrame): dataset for all samples
        sample, qtag, barcode, mcounts, reads, percent_mcounts(str): columns in df for 
            corresponding vals. Defaults are global vars SAMPLE, QTAG, BARCODE, MCOUNTS, 
            READS, PERCENT_MCOUNTS.
        min_reads(int): minimum number of reads for a library-ID-barcode as an 
            absolute baseline (that which any barcode below is highly likely to be 
            false.) Default is global var MIN_READS.
        min_mcount(int): minimum number of molecs for library-ID-barcode as an
            absolute baseline. Default is 50.

        Note: min_reads and min_mcount are applied to increase performance.

        Returns: 
            pd.DataFrame, if successful, of 'true' (passed) library-ID-barcodes 
                for all samples
            None, if no samples had passing library-ID-barcodes.
    """
    passed = []
    all_threshold_logs = {}
    counter = 1
    # checks and formats data (d) to list-like obj of pairs
    data_arr = check_data(d, sample=sample, mcounts=mcounts, reads=reads)
    # run for each (sample, df) in dataset 
    for s, group in data_arr:
        sys.stdout.write("\n-------------\nSample %d of %d (%s): "%(counter,len(data_arr),s))
        # select valid data meeting absolute baseline 
        g = group.loc[(group[qtag] != 'None') & (group[barcode] != 'None') ]
#                           & (group[mcounts] > min_mcount)
#                           & (group[reads] > min_reads)]
        if len(g)>0:
            g.loc[:,'passed'] = True
            g.loc[:,'qtag_error'] = False
            g.loc[:,'barcode_error'] = False
            g.loc[:,'is_padding'] = False
            result, tlogs = threshold(g, 20, -1, [])
            passed.append(result)
            all_threshold_logs[s] = tlogs
        sys.stdout.flush()
        counter += 1


    # if we do have data (i.e. some barcodes that passed in the samples)
    if len(passed) > 0:
        # concat all df together
        passeddf = pd.concat(passed)
        passeddf.sort_values(by=[sample,percent_mcounts]
                             ,ascending=[True, False]
                             ,inplace=True)
        passeddf.reset_index(inplace=True,drop=True)
        return passeddf, all_threshold_logs
    else:
        print "No samples were successfully thresholded."
    return

# %% [markdown]
# ### SCRIPT TO SAVE DATA TO CSVs

# %%
def save_data(filtered,passed, output_directory=OUTPUT_DIRECTORY, experiment=EXPERIMENT):
    
    # Save passed dataframe
    passed.to_csv('%s/threshold-%s-passed.csv'%(output_directory,experiment), index=False)
    # count and save results
    counts = count_sample_barcodes(passed)
    counts.to_csv('%s/threshold-%s-counts.csv'%(output_directory,experiment), index=False)
    # merge passed and filtered data and save
    fc_temp = pd.concat([d[1] for d in filtered])
    filtered_concat = apply_passed_data(fc_temp, passed)
    filtered_concat.to_csv('%s/threshold-%s-merged.csv'%(output_directory,experiment), index=False)

# %%
def count_sample_barcodes(df, groupby=SAMPLE, barcode=BARCODE, sample=SAMPLE, qtag=QTAG
                      , percent_mcounts=PERCENT_MCOUNTS):
    """Counts passed barcodes per sample and saves as csv
    
        df(pd.DataFrame): input dataframe containing passed 
            barcodes of all samples
        groupby(str or list-like): columns to group samples by
    """
    agg = df.groupby(groupby).agg(len)
    counts = agg[agg.columns[0]]
    counts.name = 'count'
    counts = pd.DataFrame(counts)
    counts.reset_index(inplace=True)
    return counts

# %%
def apply_passed_data(filtered, passeddf, sample=SAMPLE, qtag=QTAG
                      , barcode=BARCODE, percent_mcounts=PERCENT_MCOUNTS):
    """Cross reference passed barcodes with raw filtered data
        filtered(pd.DataFrame): raw filtered data as dataframe for all samples
        passed(pd.DataFrame): data passed threshold (output of run_threshold)
        sample,qtag,barcode,percent_mcounts(str): names corresponding to df columns.
            Defaults are SAMPLE,QTAG,BARCODE,PERCENT_MCOUNTS.

        Returns:
            filtered(pd.DataFrame) updated with 'passed_threshold' and 
            percent_mcounts columns
    """
    def cross_ref_passed(row):
        key = (row[sample],row[qtag],row[barcode])
        if key in passed_indexed.index:
            row.loc[:,percent_mcounts+'_thresholded'] = passed_indexed.loc[key,percent_mcounts]
            row.loc[:,'passed_threshold'] = True
        return row

    passed_indexed = passeddf.set_index([sample,qtag,barcode])
    filtered.rename(columns={percent_mcounts:percent_mcounts+'_filtered'})
    filtered.loc[:,'passed_threshold'] = False
    filtered.loc[:,percent_mcounts+'_thresholded'] = 0
    filtered = filtered.apply(cross_ref_passed, axis=1)
    return filtered

# %% [markdown]
# # EXECUTE SCRIPT BELOW

# %%
if __name__=='__main__':
    # Check all inputs exist and are valid
    check_inputs()
    # Runs data loading in script
    filtered = load_data(FILTERED_FILEPATH)
    # Run thresholding of all samples in dataset
    passeddf, all_threshold_logs = run_threshold(filtered)
#     save_data(filtered, passeddf, output_directory=OUTPUT_DIRECTORY, experiment=EXPERIMENT)
# Out:
# C:\Users\vwl698\Anaconda2\lib\site-packages\ipykernel\__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -------------
# Sample 1 of 19 (1):
# 20 37
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1768  q25  TTGCTTC      21979   True      False
# 1773  q25  TTTCTTC         89   True      False
# 1775  q24  GGTTGAT         55   True      False
# 1776  q25  TTGCTTA         55   True      False
# 1778  q19  TTGCTTC         48   True      False
# 1780  q23  TTGCTTC         28   True      False
# 1782  q25  TTGCTTT         24   True      False
# 1785  q24  TTGCTTC         22   True      False
# 1789  q25  TTGATTC         19   True      False
# 1790  q25  TTGCATC         17   True      False
# 1792  q25  TTGCCTC         13   True      False
# 1791  q25  TTGCTCC         13   True      False
# 1798  q25  TTACTTC          7   True      False
# 1799  q25  TTGCGTC          6   True      False
# 1802  q25  TTGTTTC          3   True      False
# 1809  q25  TTGCTTG          2   True      False
# 1813  q19  TTGATTC          2   True      False
# 1811  q25  TCGCTTC          2   True      False
# 1810  q25  GTGCTTC          2   True      False
# 1808  q25  ATGCTTC          2   True      False
# 1807  q25  CTGCTTC          2   True      False
# new 89
#      qtag  barcode  mcountsPF passed is_padding
# 1768  q25  TTGCTTC      21979   True      False
# 1773  q25  TTTCTTC         89   True      False
#
# 19 37
# old 89
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  TTGCTTC      21979   True      False
# 1  q25  TTTCTTC         89  False       True
# new 89
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  TTGCTTC      21979   True      False
# 1  q25  TTTCTTC         89  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q25  TTGCTTC      21979   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 2 of 19 (180-10):
# 20 81
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 110  q19  TTGTGGC       3516   True      False
# 112  q24  CGGTGTG        878   True      False
# 121  q19  TATGTTC        163   True      False
# 125  q24  TTTGGGA        152   True      False
# 127  q19  ATGATGG        134   True      False
# 129  q19  GTCTTCA        128   True      False
# 130  q19  GGGGATA        127   True      False
# 132  q25  CGTGAAC        114   True      False
# 133  q19  GTTGAAT        104   True      False
# 134  q24  GTTCCTC        101   True      False
# 135  q24  TCGCCCC         95   True      False
# 136  q19  GGGTCAC         80   True      False
# 138  q19  TTGTGTC         66   True      False
# 139  q24  TGTCCCC         62   True      False
# 140  q26  TAGTGTC         61   True      False
# 145  q19  CATCGTC         32   True      False
# 146  q24  TTGTGGC         30   True      False
# 149  q19  CTCTTGG         20   True      False
# 154  q19  TTGTGAC         17   True      False
# 153  q24  CGGTGTT         17   True      False
# 152  q19  CGGTGTG         17   True      False
# 156  q19  TCTGTTC         14   True      False
# 160  q19  CTGATGG         10   True      False
# 162  q19  GGGTGCT          8   True      False
# 163  q19  TTGTAGC          7   True      False
# 166  q19  TTTGGGA          7   True      False
# 167  q25  ACAATGA          6   True      False
# 168  q26  CGTAAAC          6   True      False
# 170  q24  CGATGTG          5   True      False
# 174  q19  TAGTGTC          4   True      False
# 178  q19  ATGATGT          4   True      False
# 176  q19  CGTGAAC          4   True      False
# 186  q24  CGGCGTG          3   True      False
# 181  q19  TCACTAT          3   True      False
# 184  q26  TCGTGTC          3   True      False
# 189  q25  TTGTGGC          3   True      False
# 197  q19  TTGTGGT          2   True      False
# 202  q19  TTGCGGC          2   True      False
# 196  q24  TATGTTC          2   True      False
# 191  q27  GTGCGTT          2   True      False
# 190  q25  GGAGCCA          2   True      False
# 192  q19  CCTTATT          2   True      False
# 200  q24  ATGATGG          2   True      False
# 198  q24  CGTGAAC          2   True      False
# new 878
#     qtag  barcode  mcountsPF passed is_padding
# 110  q19  TTGTGGC       3516   True      False
# 112  q24  CGGTGTG        878   True      False
#
# 19 81
# old 878
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TTGTGGC       3516   True      False
# 1  q24  CGGTGTG        878   True      False
# new 878
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TTGTGGC       3516   True      False
# 1  q24  CGGTGTG        878   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TTGTGGC       3516   True      False
# 1  q24  CGGTGTG        878   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 3 of 19 (180-12):
# 20 47
# old -1
#    qtag  barcode  mcountsPF passed is_padding
# 3   q19  TTGTGGC       1453   True      False
# 4   q24  CGGTGTG        707   True      False
# 11  q19  ATGATGG         74   True      False
# 14  q19  CGTCCTG         56   True      False
# 15  q27  GGGCGTC         56   True      False
# 16  q19  GTCTGGG         53   True      False
# 17  q24  TCGCCCC         52   True      False
# 20  q19  TTCGTGT         40   True      False
# 23  q24  GGCTATG         31   True      False
# 25  q19  GGCGGAA         23   True      False
# 27  q19  GTCCTGA         18   True      False
# 26  q19  TTGCAGG         18   True      False
# 28  q19  TCGCCCC         17   True      False
# 30  q19  CGGTGTG         14   True      False
# 32  q24  TTGTGGC         13   True      False
# 33  q24  CGGTGTT         11   True      False
# 37  q24  GCTTTAG          8   True      False
# 38  q27  GGTGTTA          8   True      False
# 39  q19  AGTCGAT          5   True      False
# 43  q27  GCGGTAG          4   True      False
# 45  q19  CGTCCTT          3   True      False
# 46  q19  TTGTGAC          3   True      False
# 51  q19  TTGCGGC          2   True      False
# 58  q27  TTGTGGC          2   True      False
# 52  q19  CTGGCGT          2   True      False
# 53  q19  GTCCCGA          2   True      False
# 54  q24  ATGATGG          2   True      False
# new 74
#    qtag  barcode  mcountsPF passed is_padding
# 3   q19  TTGTGGC       1453   True      False
# 4   q24  CGGTGTG        707   True      False
# 11  q19  ATGATGG         74   True      False
#
# 19 47
# old 74
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TTGTGGC       1453   True      False
# 1  q24  CGGTGTG        707   True      False
# 2  q19  ATGATGG         74   True      False
# new 74
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TTGTGGC       1453   True      False
# 1  q24  CGGTGTG        707   True      False
# 2  q19  ATGATGG         74   True      False
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TTGTGGC       1453   True      False
# 1  q24  CGGTGTG        707   True      False
# 2  q19  ATGATGG         74   True      False
# FINAL 3
# Thresholded.
#
# -------------
# Sample 4 of 19 (2):
# 20 58
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1989  q24  GGTTGAT      61172   True      False
# 1994  q24  GGTTTAT        250   True      False
# 1996  q24  GGCTGAT        143   True      False
# 1998  q24  GGTCGAT        105   True      False
# 2003  q24  TGTTGAT         69   True      False
# 2004  q24  GGTTAAT         63   True      False
# 2005  q24  GGGTGAT         54   True      False
# 2008  q24  GTTTGAT         41   True      False
# 2012  q24  GGATGAT         27   True      False
# 2014  q24  GGTAGAT         23   True      False
# 2016  q24  GGTTGTT         18   True      False
# 2018  q24  GGTGGAT         16   True      False
# 2019  q19  GGTTGAT         14   True      False
# 2022  q24  GGTTGAC         12   True      False
# 2021  q24  GGTTCAT         12   True      False
# 2023  q24  GATTGAT          9   True      False
# 2024  q24  GGTTGCT          8   True      False
# 2026  q23  GGTTGAT          6   True      False
# 2029  q24  AGTTGAT          5   True      False
# 2031  q24  GGTTGAG          5   True      False
# 2036  q24  GAGTGTG          4   True      False
# 2034  q24  GGTTGGT          4   True      False
# 2045  q24  GATCCAT          3   True      False
# 2041  q24  GGCCGAT          3   True      False
# 2040  q24  GGGTTAT          3   True      False
# 2043  q24  GGTTGAA          3   True      False
# 2053  q24  TGTATGG          2   True      False
# 2059  q24  TGGATGG          2   True      False
# 2052  q24  GGTTTTT          2   True      False
# 2055  q25  GGTTGAT          2   True      False
# 2048  q24  GGTCCAT          2   True      False
# 2062  q24  GCTTGAT          2   True      False
# 2057  q24  GGATGAC          2   True      False
# new 250
#      qtag  barcode  mcountsPF passed is_padding
# 1989  q24  GGTTGAT      61172   True      False
# 1994  q24  GGTTTAT        250   True      False
#
# 19 58
# old 250
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GGTTGAT      61172   True      False
# 1  q24  GGTTTAT        250  False       True
# new 250
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GGTTGAT      61172   True      False
# 1  q24  GGTTTAT        250  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GGTTGAT      61172   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 5 of 19 (20):
# 20 140
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 664  q19  GATCCAT     189720   True      False
# 670  q23  GATCCAT        247   True      False
# 673  q19  GATACAT        226   True      False
# 674  q24  GATCCAT        205   True      False
# 675  q19  GATCAAT        194   True      False
# 676  q19  GATTCAT        183   True      False
# 678  q19  GATCCAC        141   True      False
# 681  q19  GATCTAT        111   True      False
# 686  q19  GACCCAT         85   True      False
# 692  q19  GATCCGT         61   True      False
# 693  q19  TATCCAT         61   True      False
# 695  q19  GATCCCT         51   True      False
# 697  q19  GCTCCAT         46   True      False
# 696  q19  GATTTAT         46   True      False
# 698  q19  GATCCTT         45   True      False
# 700  q19  GATCCAG         39   True      False
# 701  q23  GTTTCTG         37   True      False
# 706  q19  GGTCCAT         31   True      False
# 709  q19  GATCCAA         29   True      False
# 710  q19  AATCCAT         27   True      False
# 711  q19  GTTCCAT         25   True      False
# 712  q19  GAACCAT         24   True      False
# 713  q19  GATGCAT         22   True      False
# 714  q19  TGTATGG         19   True      False
# 715  q24  CTAAATT         17   True      False
# 717  q19  GAGCCAT         13   True      False
# 718  q19  GATCGAT         11   True      False
# 720  q19  GTTTCTG         10   True      False
# 722  q19  ATCCTTT          9   True      False
# 723  q19  GAACTTC          9   True      False
# 726  q27  GATCCAT          9   True      False
# 724  q24  GTTTCTG          9   True      False
# 733  q19  CATCCAT          7   True      False
# 731  q19  CCGCTTT          7   True      False
# 736  q19  GTTCCTT          6   True      False
# 738  q23  GATTCAT          5   True      False
# 737  q24  GGGATAT          5   True      False
# 741  q25  GATCCAT          5   True      False
# 739  q23  GATCCAG          5   True      False
# 763  q24  GATACAT          3   True      False
# 761  q19  GATCATT          3   True      False
# 768  q26  GATCCAT          3   True      False
# 755  q19  GATCTTT          3   True      False
# 759  q19  GATTCTT          3   True      False
# 794  q23  GATCCTT          2   True      False
# 775  q19  TGTCCAT          2   True      False
# 771  q19  TGATGCC          2   True      False
# 787  q19  GCTCCTT          2   True      False
# 800  q23  GCCCCTG          2   True      False
# 791  q19  GATTCAG          2   True      False
# 796  q19  GATAAAT          2   True      False
# 790  q24  GATCCTT          2   True      False
# 792  q19  GAACCTC          2   True      False
# 783  q24  CTAACTT          2   True      False
# 772  q23  CTAAATT          2   True      False
# 782  q19  CCACCGC          2   True      False
# new 247
#     qtag  barcode  mcountsPF passed is_padding
# 664  q19  GATCCAT     189720   True      False
# 670  q23  GATCCAT        247   True      False
#
# 19 140
# old 247
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GATCCAT     189720   True      False
# 1  q23  GATCCAT        247  False       True
# new 247
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GATCCAT     189720   True      False
# 1  q23  GATCCAT        247  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GATCCAT     189720   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 6 of 19 (21):
# 20 27
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 982   q23  GTTTCTG      13552   True      False
# 986   q23  GTTTCTT         41   True      False
# 991   q23  GTTTCCG         16   True      False
# 992   q23  TTTTCTG         15   True      False
# 996   q23  GTTCCTG         10   True      False
# 999   q23  GTTTATG          9   True      False
# 998   q23  GTTTCTA          9   True      False
# 1002  q19  GATCCAT          5   True      False
# 1010  q23  GCTTCTG          3   True      False
# 1007  q23  GTTGCTG          3   True      False
# 1011  q19  GTTTCTG          3   True      False
# 1013  q24  GTTTCTG          3   True      False
# 1021  q23  GTTTCTC          2   True      False
# 1014  q23  GTTTTTG          2   True      False
# 1016  q23  GGTTCTG          2   True      False
# 1017  q23  GTTTCAG          2   True      False
# 1015  q23  GATTCTG          2   True      False
# new 41
#     qtag  barcode  mcountsPF passed is_padding
# 982  q23  GTTTCTG      13552   True      False
# 986  q23  GTTTCTT         41   True      False
#
# 19 27
# old 41
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      13552   True      False
# 1  q23  GTTTCTT         41  False       True
# new 41
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      13552   True      False
# 1  q23  GTTTCTT         41  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      13552   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 7 of 19 (22):
# 20 91
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1056  q23  GTTTCTG     166365   True      False
# 1062  q23  GTTTCTA        364   True      False
# 1063  q23  GTTTCCG        360   True      False
# 1067  q23  GTTTCTT        190   True      False
# 1071  q23  GTTTTTG        121   True      False
# 1072  q23  GTTCCTG        115   True      False
# 1073  q23  GTTTCAG        112   True      False
# 1075  q23  GTTTATG         95   True      False
# 1077  q23  GCTTCTG         87   True      False
# 1079  q19  GTTTCTG         78   True      False
# 1082  q23  TTTTCTG         65   True      False
# 1084  q24  GTTTCTG         63   True      False
# 1086  q23  GTTTCGG         40   True      False
# 1087  q23  GTTACTG         36   True      False
# 1088  q19  GATCCAT         32   True      False
# 1090  q23  GTCTCTG         32   True      False
# 1091  q23  GATTCTG         31   True      False
# 1094  q23  ATTTCTG         25   True      False
# 1095  q23  GTTTCTC         23   True      False
# 1096  q23  GTTGCTG         21   True      False
# 1098  q23  GGTTCTG         20   True      False
# 1105  q23  GATCCAT         10   True      False
# 1106  q23  GTATCTG         10   True      False
# 1109  q23  GTGTCTG          7   True      False
# 1111  q23  GTTTGTG          6   True      False
# 1116  q19  GGGCTGG          5   True      False
# 1114  q23  TGTATGG          5   True      False
# 1121  q23  GTTCTTG          4   True      False
# 1128  q23  CTTTCTG          3   True      False
# 1127  q23  GCTCCTG          3   True      False
# 1141  q25  GTTTCTG          2   True      False
# 1145  q23  TGTTCTG          2   True      False
# 1147  q23  TGTTATG          2   True      False
# 1155  q19  TGTATGG          2   True      False
# 1137  q23  GCCCCTG          2   True      False
# 1154  q23  GTTGCGG          2   True      False
# 1140  q23  GATTCTT          2   True      False
# 1143  q24  CTAAATT          2   True      False
# new 364
#      qtag  barcode  mcountsPF passed is_padding
# 1056  q23  GTTTCTG     166365   True      False
# 1062  q23  GTTTCTA        364   True      False
#
# 19 91
# old 364
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG     166365   True      False
# 1  q23  GTTTCTA        364  False       True
# new 364
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG     166365   True      False
# 1  q23  GTTTCTA        364  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG     166365   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 8 of 19 (23):
# 20 34
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1266  q24  GCGTCTC      15262   True      False
# 1270  q24  GCGTCTT         30   True      False
# 1271  q24  GCTTCTC         29   True      False
# 1278  q24  GCATCTC         18   True      False
# 1283  q24  GCGTCCC         14   True      False
# 1284  q19  GATCCAT         12   True      False
# 1285  q24  GGGATAT         12   True      False
# 1286  q24  GCGTTTC         11   True      False
# 1287  q24  GCGCCTC         10   True      False
# 1288  q24  GTGTCTC         10   True      False
# 1293  q24  GAGTCTC          8   True      False
# 1295  q24  GCGTATC          5   True      False
# 1296  q24  GCGTCTA          5   True      False
# 1294  q23  GTTTCTG          5   True      False
# 1300  q24  GCGGCTC          4   True      False
# 1299  q23  GCGTCTC          4   True      False
# 1303  q24  GCGTCAC          3   True      False
# 1306  q19  ATCCTTT          3   True      False
# 1310  q24  GCGTCGC          2   True      False
# 1312  q19  GCGTCTC          2   True      False
# 1314  q24  TCGTCTC          2   True      False
# 1308  q24  GCCTCTC          2   True      False
# new 30
#      qtag  barcode  mcountsPF passed is_padding
# 1266  q24  GCGTCTC      15262   True      False
# 1270  q24  GCGTCTT         30   True      False
#
# 19 34
# old 30
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCGTCTC      15262   True      False
# 1  q24  GCGTCTT         30  False       True
# new 30
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCGTCTC      15262   True      False
# 1  q24  GCGTCTT         30  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GCGTCTC      15262   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 9 of 19 (24):
# 20 44
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 298  q24  GGGATAT      21939   True      False
# 302  q24  GGAATAT         64   True      False
# 306  q24  GGTATAT         43   True      False
# 310  q24  TGGATAT         21   True      False
# 312  q19  GATCCAT         19   True      False
# 313  q24  GGGTTAT         19   True      False
# 315  q23  GTTTCTG         17   True      False
# 316  q24  GGGCTAT         16   True      False
# 322  q24  GGGACAT         11   True      False
# 325  q24  GGGATTT          9   True      False
# 327  q24  GTGATAT          8   True      False
# 329  q24  GGGATAC          7   True      False
# 328  q24  GGGAAAT          7   True      False
# 331  q24  GCGTCTC          6   True      False
# 334  q24  GGCATAT          5   True      False
# 333  q19  GGGATAT          5   True      False
# 335  q24  GGGGTAT          5   True      False
# 336  q24  GGTTGAT          5   True      False
# 337  q19  TGTATGG          5   True      False
# 338  q24  GAGATAT          4   True      False
# 340  q24  GGGATCT          4   True      False
# 348  q23  GCCCCTG          3   True      False
# 353  q24  GGTCTAT          2   True      False
# 356  q24  GTTTCTG          2   True      False
# 351  q24  GGGATAA          2   True      False
# 352  q24  GGGCCAT          2   True      False
# 349  q23  GGGATAT          2   True      False
# new 64
#     qtag  barcode  mcountsPF passed is_padding
# 298  q24  GGGATAT      21939   True      False
# 302  q24  GGAATAT         64   True      False
#
# 19 44
# old 64
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GGGATAT      21939   True      False
# 1  q24  GGAATAT         64  False       True
# new 64
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GGGATAT      21939   True      False
# 1  q24  GGAATAT         64  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GGGATAT      21939   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 10 of 19 (25):
# 20 51
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 401  q19  TGTATGG      42568   True      False
# 406  q19  TGTACGG         58   True      False
# 411  q19  TGTATGA         43   True      False
# 414  q19  TGTATGT         34   True      False
# 413  q19  TTTATGG         34   True      False
# 416  q19  TGTATTG         28   True      False
# 417  q24  TGTATGG         26   True      False
# 419  q23  TGTATGG         25   True      False
# 418  q19  TGTCTGG         25   True      False
# 420  q19  TGTTTGG         22   True      False
# 422  q19  TGCATGG         18   True      False
# 427  q19  TGTGTGG         14   True      False
# 430  q19  TGTATAG         10   True      False
# 432  q19  CGTATGG         10   True      False
# 431  q23  GTTTCTG         10   True      False
# 435  q19  GATCCAT          8   True      False
# 436  q19  TGGATGG          7   True      False
# 439  q19  TGAATGG          6   True      False
# 437  q19  TGTAAGG          6   True      False
# 446  q19  TGTATAA          3   True      False
# 444  q19  TGTATGC          3   True      False
# 454  q19  TGTATTT          2   True      False
# 449  q19  TGTATCG          2   True      False
# 455  q19  TGTAGGG          2   True      False
# 456  q19  TGCCTGG          2   True      False
# 453  q19  TATATGG          2   True      False
# 458  q24  GAGTGTG          2   True      False
# 451  q19  GAACTTC          2   True      False
# 457  q23  GATCCAT          2   True      False
# new 58
#     qtag  barcode  mcountsPF passed is_padding
# 401  q19  TGTATGG      42568   True      False
# 406  q19  TGTACGG         58   True      False
#
# 19 51
# old 58
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TGTATGG      42568   True      False
# 1  q19  TGTACGG         58  False       True
# new 58
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TGTATGG      42568   True      False
# 1  q19  TGTACGG         58  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TGTATGG      42568   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 11 of 19 (26):
# 20 31
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 502  q19  TGTATGG      21539   True      False
# 509  q19  TGTATGT         23   True      False
# 511  q23  TGTATGG         21   True      False
# 512  q19  TGTACGG         20   True      False
# 515  q19  TGTATTG         16   True      False
# 517  q19  TGTATGA         14   True      False
# 516  q24  TGTATGG         14   True      False
# 518  q19  TGTCTGG         13   True      False
# 522  q19  TGTTTGG         10   True      False
# 524  q19  TGAATGG          9   True      False
# 526  q19  TGCATGG          6   True      False
# 528  q19  TGTGTGG          5   True      False
# 533  q19  TGTATAG          4   True      False
# 530  q19  TTTATGG          4   True      False
# 531  q19  TGGATGG          4   True      False
# 534  q19  TATATGG          4   True      False
# 538  q19  TGTAAGG          3   True      False
# 541  q19  GGTGGGC          2   True      False
# 539  q19  TGTAGGG          2   True      False
# 540  q19  TGTATCG          2   True      False
# new 23
#     qtag  barcode  mcountsPF passed is_padding
# 502  q19  TGTATGG      21539   True      False
# 509  q19  TGTATGT         23   True      False
#
# 19 31
# old 23
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TGTATGG      21539   True      False
# 1  q19  TGTATGT         23  False       True
# new 23
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TGTATGG      21539   True      False
# 1  q19  TGTATGT         23  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  TGTATGG      21539   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 12 of 19 (27):
# 20 49
# old -1
#     qtag  barcode  mcountsPF passed is_padding
# 565  q19  ATCCTTT      24880   True      False
# 571  q19  ATCCCTT         36   True      False
# 572  q19  TGTATGG         28   True      False
# 574  q19  ATCATTT         22   True      False
# 580  q19  ATCCATT         13   True      False
# 585  q19  ATCTTTT         10   True      False
# 588  q23  ATCCTTT          8   True      False
# 591  q24  ATCCTTT          8   True      False
# 594  q19  GATCCAT          7   True      False
# 595  q19  GGTGGGC          7   True      False
# 596  q19  GAACTTC          6   True      False
# 603  q19  ATCCGTT          5   True      False
# 601  q19  ATCCTAT          5   True      False
# 597  q19  ATCCTTA          5   True      False
# 598  q19  ATCCTTC          5   True      False
# 600  q19  ATTCTTT          5   True      False
# 605  q19  CTCCTTT          4   True      False
# 604  q19  ATCCTCT          4   True      False
# 610  q19  ATCCTTG          3   True      False
# 608  q19  TTCCTTT          3   True      False
# 611  q19  AACCTTT          3   True      False
# 612  q19  ATCCTGT          2   True      False
# 613  q27  ATCCTTT          2   True      False
# new 36
#     qtag  barcode  mcountsPF passed is_padding
# 565  q19  ATCCTTT      24880   True      False
# 571  q19  ATCCCTT         36   True      False
#
# 19 49
# old 36
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  ATCCTTT      24880   True      False
# 1  q19  ATCCCTT         36  False       True
# new 36
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  ATCCTTT      24880   True      False
# 1  q19  ATCCCTT         36  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  ATCCTTT      24880   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 13 of 19 (28):
# 20 125
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1343  q23  GTTTCTG      28217   True      False
# 1344  q19  TGTATGG      21353   True      False
# 1346  q24  GGGATAT      12084   True      False
# 1347  q19  GTTTCTG       1458   True      False
# 1348  q23  TGTATGG       1315   True      False
# 1350  q24  GTTTCTG       1018   True      False
# 1351  q24  TGTATGG        791   True      False
# 1352  q23  GGGATAT        682   True      False
# 1353  q19  GGGATAT        601   True      False
# 1362  q24  GGAATAT         40   True      False
# 1366  q23  GTTTCTA         37   True      False
# 1372  q19  TGTATGT         27   True      False
# 1370  q24  GGTATAT         27   True      False
# 1374  q23  GTTTCCG         23   True      False
# 1376  q19  TGTCTGG         22   True      False
# 1380  q19  TGTACGG         17   True      False
# 1383  q23  GCTTCTG         14   True      False
# 1386  q23  GTTTCTT         14   True      False
# 1384  q19  TGTATTG         14   True      False
# 1391  q19  TGCATGG         12   True      False
# 1389  q19  TGTATGA         12   True      False
# 1397  q24  GGGTTAT         10   True      False
# 1395  q19  TTTATGG         10   True      False
# 1402  q19  TGTGTGG          9   True      False
# 1401  q19  TGTTTGG          9   True      False
# 1399  q23  GTTTCAG          9   True      False
# 1400  q24  TGGATAT          9   True      False
# 1404  q24  GGGCTAT          9   True      False
# 1407  q24  GTGATAT          8   True      False
# 1405  q19  TATATGG          8   True      False
# ...   ...      ...        ...    ...        ...
# 1409  q24  GGGATTT          7   True      False
# 1411  q23  GTTTATG          7   True      False
# 1410  q23  TTTTCTG          7   True      False
# 1423  q23  TGTACGG          6   True      False
# 1421  q19  TGTATAG          6   True      False
# 1422  q23  GTTTTTG          6   True      False
# 1417  q23  GTTCCTG          6   True      False
# 1426  q23  GTCTCTG          5   True      False
# 1433  q23  ATTTCTG          4   True      False
# 1428  q19  GAACTTC          4   True      False
# 1429  q23  GGTTCTG          4   True      False
# 1434  q23  GTTTCTC          4   True      False
# 1435  q19  TGGATGG          4   True      False
# 1438  q19  GTTTATG          3   True      False
# 1440  q19  TGTAAGG          3   True      False
# 1441  q19  TCTATGG          3   True      False
# 1437  q23  GTTTCGG          3   True      False
# 1444  q24  GGGATAG          3   True      False
# 1442  q23  GTTACTG          3   True      False
# 1443  q24  GGCATAT          3   True      False
# 1436  q19  GGTGGGC          3   True      False
# 1439  q19  CGTATGG          3   True      False
# 1459  q24  AGGATAT          2   True      False
# 1463  q24  GGGAAAT          2   True      False
# 1467  q23  GGGACAT          2   True      False
# 1469  q23  GGGTTAT          2   True      False
# 1464  q23  GGTATAT          2   True      False
# 1449  q23  TGGATAT          2   True      False
# 1454  q19  TGGATAT          2   True      False
# 1466  q23  GGAATAT          2   True      False
#
# [61 rows x 5 columns]
# new 40
#      qtag  barcode  mcountsPF passed is_padding
# 1343  q23  GTTTCTG      28217   True      False
# 1344  q19  TGTATGG      21353   True      False
# 1346  q24  GGGATAT      12084   True      False
# 1347  q19  GTTTCTG       1458   True      False
# 1348  q23  TGTATGG       1315   True      False
# 1350  q24  GTTTCTG       1018   True      False
# 1351  q24  TGTATGG        791   True      False
# 1352  q23  GGGATAT        682   True      False
# 1353  q19  GGGATAT        601   True      False
# 1362  q24  GGAATAT         40   True      False
#
# 19 125
# old 40
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28217   True      False
# 1  q19  TGTATGG      21353   True      False
# 2  q24  GGGATAT      12084   True      False
# 3  q19  GTTTCTG       1458  False       True
# 4  q23  TGTATGG       1315  False      False
# 5  q24  GTTTCTG       1018  False      False
# 6  q24  TGTATGG        791  False      False
# 7  q23  GGGATAT        682  False      False
# 8  q19  GGGATAT        601  False      False
# 9  q24  GGAATAT         40  False      False
# new 1458
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28217   True      False
# 1  q19  TGTATGG      21353   True      False
# 2  q24  GGGATAT      12084   True      False
# 3  q19  GTTTCTG       1458  False       True
#
# 18 125
# old 1458
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28217   True      False
# 1  q19  TGTATGG      21353   True      False
# 2  q24  GGGATAT      12084   True      False
# 3  q19  GTTTCTG       1458  False       True
# new 1458
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28217   True      False
# 1  q19  TGTATGG      21353   True      False
# 2  q24  GGGATAT      12084   True      False
# 3  q19  GTTTCTG       1458  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28217   True      False
# 1  q19  TGTATGG      21353   True      False
# 2  q24  GGGATAT      12084   True      False
# FINAL 3
# Thresholded.
#
# -------------
# Sample 14 of 19 (29):
# 20 80
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1574  q19  GGTGGGC      68425   True      False
# 1579  q19  GGTGTGC        584   True      False
# 1581  q19  GGTTGGC        456   True      False
# 1582  q19  GGTGGAC        279   True      False
# 1586  q19  GGTGAGC        127   True      False
# 1590  q19  GGTAGGC         84   True      False
# 1591  q19  GGCGGGC         74   True      False
# 1593  q19  GGTGCGC         66   True      False
# 1594  q23  GGTGGGC         65   True      False
# 1595  q19  GGTGGGA         58   True      False
# 1596  q24  GGTGGGC         54   True      False
# 1599  q19  GGTGGTC         42   True      False
# 1603  q19  GGTCGGC         34   True      False
# 1604  q19  GGGGGGC         33   True      False
# 1606  q19  GGTGGGT         24   True      False
# 1607  q19  GTTGGGC         21   True      False
# 1609  q19  GGAGGGC         18   True      False
# 1610  q19  TGTATGG         16   True      False
# 1614  q19  GGTGGCC         12   True      False
# 1619  q19  AGTGGGC          8   True      False
# 1617  q19  GATGGGC          8   True      False
# 1618  q23  GTTTCTG          8   True      False
# 1616  q19  TGTGGGC          8   True      False
# 1625  q23  GGTTGGC          5   True      False
# 1629  q19  GGTGGGG          4   True      False
# 1631  q19  GGTTCGC          4   True      False
# 1632  q19  GGTTTGC          4   True      False
# 1634  q25  GGTGGGC          3   True      False
# 1633  q26  GGTGGGC          3   True      False
# 1639  q19  GGGGGGG          3   True      False
# 1642  q19  ATCCTTT          3   True      False
# 1651  q19  GGTTAGC          2   True      False
# 1647  q19  GATCCAT          2   True      False
# 1648  q19  GCTGGGC          2   True      False
# 1654  q19  GGTCTGC          2   True      False
# 1652  q24  GGTGAGC          2   True      False
# 1655  q27  GGTGGGC          2   True      False
# 1649  q19  GGTGTAC          2   True      False
# 1653  q24  GGTGTGC          2   True      False
# 1650  q19  GGTGTTC          2   True      False
# new 584
#      qtag  barcode  mcountsPF passed is_padding
# 1574  q19  GGTGGGC      68425   True      False
# 1579  q19  GGTGTGC        584   True      False
#
# 19 80
# old 584
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGTGGGC      68425   True      False
# 1  q19  GGTGTGC        584  False       True
# new 584
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGTGGGC      68425   True      False
# 1  q19  GGTGTGC        584  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GGTGGGC      68425   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 15 of 19 (3):
# 20 55
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 1852  q24  GAGTGTG      14220   True      False
# 1853  q23  AGTTATT       9876   True      False
# 1854  q23  GAGTGTG        614   True      False
# 1855  q24  AGTTATT        607   True      False
# 1862  q24  GAGTTTG         34   True      False
# 1865  q24  GAGTGCG         20   True      False
# 1866  q24  GAGCGTG         19   True      False
# 1867  q24  GAGTATG         18   True      False
# 1871  q24  GATTGTG         17   True      False
# 1873  q23  AGTTCTT         13   True      False
# 1875  q24  GAGTGTT         11   True      False
# 1878  q24  GAGTGTA          9   True      False
# 1879  q23  AGCTATT          9   True      False
# 1886  q24  GAGTGAG          6   True      False
# 1884  q24  TAGTGTG          6   True      False
# 1896  q19  AGTTATT          4   True      False
# 1897  q23  TGTTATT          4   True      False
# 1898  q23  AGTCATT          3   True      False
# 1902  q24  GAGTCTG          3   True      False
# 1900  q24  GCGTGTG          3   True      False
# 1916  q24  GAGGGTG          2   True      False
# 1908  q24  GTGTGTG          2   True      False
# 1913  q23  GATTGTG          2   True      False
# 1915  q24  GAGTGGG          2   True      False
# 1903  q23  GAGTGTT          2   True      False
# 1907  q23  GAGAGTG          2   True      False
# 1904  q23  AGTTGTT          2   True      False
# 1912  q23  AGTTATC          2   True      False
# 1914  q23  AGTTATA          2   True      False
# 1906  q23  AGTTTTT          2   True      False
# new 34
#      qtag  barcode  mcountsPF passed is_padding
# 1852  q24  GAGTGTG      14220   True      False
# 1853  q23  AGTTATT       9876   True      False
# 1854  q23  GAGTGTG        614   True      False
# 1855  q24  AGTTATT        607   True      False
# 1862  q24  GAGTTTG         34   True      False
#
# 19 55
# old 34
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GAGTGTG      14220   True      False
# 1  q23  AGTTATT       9876   True      False
# 2  q23  GAGTGTG        614  False       True
# 3  q24  AGTTATT        607  False      False
# 4  q24  GAGTTTG         34  False      False
# new 614
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GAGTGTG      14220   True      False
# 1  q23  AGTTATT       9876   True      False
# 2  q23  GAGTGTG        614  False       True
#
# 18 55
# old 614
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GAGTGTG      14220   True      False
# 1  q23  AGTTATT       9876   True      False
# 2  q23  GAGTGTG        614  False       True
# new 614
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GAGTGTG      14220   True      False
# 1  q23  AGTTATT       9876   True      False
# 2  q23  GAGTGTG        614  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q24  GAGTGTG      14220   True      False
# 1  q23  AGTTATT       9876   True      False
# FINAL 2
# Thresholded.
#
# -------------
# Sample 16 of 19 (4):
# 20 30
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 2315  q23  GTTTCTG      28058   True      False
# 2321  q23  GTTTCTT         44   True      False
# 2322  q23  GTTTCCG         27   True      False
# 2326  q23  GTTTCTA         21   True      False
# 2327  q23  GTTTATG         16   True      False
# 2330  q23  TTTTCTG         15   True      False
# 2332  q24  GTTTCTG         11   True      False
# 2334  q23  GTTTTTG          9   True      False
# 2336  q19  GTTTCTG          7   True      False
# 2337  q23  GCTTCTG          6   True      False
# 2338  q23  GTTTCAG          5   True      False
# 2339  q23  GTTACTG          4   True      False
# 2342  q23  GTTCCTG          4   True      False
# 2346  q23  GGTTCTG          3   True      False
# 2347  q23  GTCTCTG          3   True      False
# 2345  q23  ATTTCTG          3   True      False
# 2349  q23  CTTTCTG          2   True      False
# 2350  q23  GTGTCTG          2   True      False
# new 44
#      qtag  barcode  mcountsPF passed is_padding
# 2315  q23  GTTTCTG      28058   True      False
# 2321  q23  GTTTCTT         44   True      False
#
# 19 30
# old 44
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28058   True      False
# 1  q23  GTTTCTT         44  False       True
# new 44
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28058   True      False
# 1  q23  GTTTCTT         44  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      28058   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 17 of 19 (5):
# 20 66
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 2144  q19  GAACTTC     103126   True      False
# 2153  q23  GAACTTC         81   True      False
# 2154  q24  GAACTTC         77   True      False
# 2155  q19  GAACATC         76   True      False
# 2156  q19  GAAATTC         73   True      False
# 2157  q19  GAACTCC         73   True      False
# 2158  q19  GAACCTC         71   True      False
# 2159  q19  GAACTTT         66   True      False
# 2160  q19  GAACTTA         62   True      False
# 2165  q19  GAACGTC         39   True      False
# 2166  q19  TAACTTC         39   True      False
# 2169  q19  GAATTTC         31   True      False
# 2172  q19  AAACTTC         25   True      False
# 2175  q19  GGACTTC         18   True      False
# 2177  q19  GATCTTC         16   True      False
# 2181  q19  GAACTAC         14   True      False
# 2180  q19  GTACTTC         14   True      False
# 2183  q19  GCACTTC         12   True      False
# 2185  q19  GAGCTTC         10   True      False
# 2187  q19  GATCCAT          8   True      False
# 2188  q23  GTTTCTG          8   True      False
# 2190  q23  ATTGTGT          7   True      False
# 2193  q19  GAACTTG          6   True      False
# 2192  q19  GACCTTC          6   True      False
# 2194  q19  GAACCTT          6   True      False
# 2195  q19  GAACTGC          5   True      False
# 2197  q25  GAACTTC          4   True      False
# 2204  q19  GAAGTTC          3   True      False
# 2201  q19  GAATCTC          3   True      False
# 2215  q19  TGAATGG          2   True      False
# 2212  q19  CAACTTC          2   True      False
# 2219  q19  GGGCTGG          2   True      False
# 2216  q19  GTTTCTG          2   True      False
# new 81
#      qtag  barcode  mcountsPF passed is_padding
# 2144  q19  GAACTTC     103126   True      False
# 2153  q23  GAACTTC         81   True      False
#
# 19 66
# old 81
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GAACTTC     103126   True      False
# 1  q23  GAACTTC         81  False       True
# new 81
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GAACTTC     103126   True      False
# 1  q23  GAACTTC         81  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q19  GAACTTC     103126   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 18 of 19 (6):
# 20 32
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 2477  q23  GTTTCTG      23803   True      False
# 2482  q23  GTTTCTA         28   True      False
# 2484  q23  GTTTCCG         22   True      False
# 2488  q23  GTTTCTT         14   True      False
# 2494  q23  GCTTCTG          7   True      False
# 2493  q23  GGTTCTG          7   True      False
# 2495  q24  GTTTCTG          7   True      False
# 2496  q23  TTTTCTG          7   True      False
# 2497  q23  GTTCCTG          6   True      False
# 2498  q23  GTTTATG          6   True      False
# 2501  q23  GTTTTTG          5   True      False
# 2503  q23  GTTTCAG          4   True      False
# 2505  q19  GAACTTC          3   True      False
# 2504  q23  GTTACTG          3   True      False
# 2510  q23  GTTTCTC          2   True      False
# 2517  q23  GTTTGTG          2   True      False
# 2511  q23  GTTTCGG          2   True      False
# new 28
#      qtag  barcode  mcountsPF passed is_padding
# 2477  q23  GTTTCTG      23803   True      False
# 2482  q23  GTTTCTA         28   True      False
#
# 19 32
# old 28
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      23803   True      False
# 1  q23  GTTTCTA         28  False       True
# new 28
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      23803   True      False
# 1  q23  GTTTCTA         28  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  GTTTCTG      23803   True      False
# FINAL 1
# Thresholded.
#
# -------------
# Sample 19 of 19 (7):
# 20 38
# old -1
#      qtag  barcode  mcountsPF passed is_padding
# 2385  q23  ATTGTGT      28025   True      False
# 2389  q23  ATTTTGT        138   True      False
# 2391  q23  ATTGCGT         69   True      False
# 2394  q23  ATTGTGC         29   True      False
# 2398  q23  ATTGTAT         18   True      False
# 2399  q23  ATTATGT         16   True      False
# 2400  q23  ATTGTTT         14   True      False
# 2407  q23  ATTGTGG          9   True      False
# 2411  q24  ATTGTGT          8   True      False
# 2413  q23  ATCGTGT          6   True      False
# 2414  q23  ATTGGGT          5   True      False
# 2419  q19  GAACTTC          4   True      False
# 2421  q23  TTTGTGT          4   True      False
# 2416  q19  TGATGCC          4   True      False
# 2417  q23  ACTGTGT          4   True      False
# 2420  q23  ATTGAGT          4   True      False
# 2418  q23  ATTCTGT          4   True      False
# 2424  q23  ATTGCGG          3   True      False
# 2427  q23  ATTTCGT          3   True      False
# 2436  q23  GATCCAT          2   True      False
# 2429  q23  GTTTCTG          2   True      False
# 2430  q23  GTTGTGT          2   True      False
# 2431  q19  GGTGGGC          2   True      False
# 2439  q27  ATCCGTT          2   True      False
# 2440  q23  CTTGTGT          2   True      False
# 2433  q19  ATTGTGT          2   True      False
# 2438  q23  ATTCCGT          2   True      False
# new 138
#      qtag  barcode  mcountsPF passed is_padding
# 2385  q23  ATTGTGT      28025   True      False
# 2389  q23  ATTTTGT        138   True      False
#
# 19 38
# old 138
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  ATTGTGT      28025   True      False
# 1  q23  ATTTTGT        138  False       True
# new 138
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  ATTGTGT      28025   True      False
# 1  q23  ATTTTGT        138  False       True
# final
#   qtag  barcode  mcountsPF passed is_padding
# 0  q23  ATTGTGT      28025   True      False
# FINAL 1
# Thresholded.

# %%
fconcat = pd.concat([d[1] for d in filtered if d[0][:2]!="VL" ])
merged = fconcat.merge(passeddf, 
              on=['idx','qtag','barcode','mcountsPF','readsPF'], 
                       how='outer')
merged.drop(['percent_mcountsPF_x','is_padding'],axis=1, inplace=True)
merged.rename(columns={'percent_mcountsPF_y':"percent_mcountsPF"}, inplace=True)
merged = merged.fillna(value={'passed':False,'qtag_error':False,'barcode_error':False,
                    'percent_mcountsPF':0.})

# %%
merged.loc[(merged['passed']==True)|(merged.mcountsPF > 300)]
# Out:
#          idx qtag  barcode  mcountsPF  readsPF  percent_mcountsPF passed  \
# 0          1  q25  TTGCTTC      21979    23011         100.000000   True
# 37    180-10  q19  TTGTGGC       3516     4600          80.018207   True
# 38    180-10  q24  CGGTGTG        878     1104          19.981793   True
# 118   180-12  q19  TTGTGGC       1453     1616          65.040286   True
# 119   180-12  q24  CGGTGTG        707      746          31.647269   True
# 120   180-12  q19  ATGATGG         74       75           3.312444   True
# 165        2  q24  GGTTGAT      61172    68931         100.000000   True
# 223       20  q19  GATCCAT     189720   465296         100.000000   True
# 363       21  q23  GTTTCTG      13552    13456         100.000000   True
# 390       22  q23  GTTTCTG     166365   339984         100.000000   True
# 391       22  q23  GTTTCTA        364      316           0.000000  False
# 392       22  q23  GTTTCCG        360      307           0.000000  False
# 481       23  q24  GCGTCTC      15262    15289         100.000000   True
# 515       24  q24  GGGATAT      21939    22133         100.000000   True
# 559       25  q19  TGTATGG      42568    48312         100.000000   True
# 610       26  q19  TGTATGG      21539    22583         100.000000   True
# 641       27  q19  ATCCTTT      24880    26404         100.000000   True
# 690       28  q23  GTTTCTG      28217    29812          45.766698   True
# 691       28  q19  TGTATGG      21353    21946          34.633600   True
# 692       28  q24  GGGATAT      12084    11757          19.599702   True
# 693       28  q19  GTTTCTG       1458     1372           0.000000  False
# 694       28  q23  TGTATGG       1315     1225           0.000000  False
# 695       28  q24  GTTTCTG       1018      917           0.000000  False
# 696       28  q24  TGTATGG        791      716           0.000000  False
# 697       28  q23  GGGATAT        682      604           0.000000  False
# 698       28  q19  GGGATAT        601      533           0.000000  False
# 815       29  q19  GGTGGGC      68425    78713         100.000000   True
# 816       29  q19  GGTGTGC        584       32           0.000000  False
# 817       29  q19  GGTTGGC        456       49           0.000000  False
# 895        3  q24  GAGTGTG      14220    13854          59.013944   True
# 896        3  q23  AGTTATT       9876     9396          40.986056   True
# 897        3  q23  GAGTGTG        614      560           0.000000  False
# 898        3  q24  AGTTATT        607      532           0.000000  False
# 950        4  q23  GTTTCTG      28058    30154         100.000000   True
# 980        5  q19  GAACTTC     103126   149848         100.000000   True
# 1046       6  q23  GTTTCTG      23803    24691         100.000000   True
# 1078       7  q23  ATTGTGT      28025    28960         100.000000   True
#
#      qtag_error barcode_error
# 0         False         False
# 37        False         False
# 38        False         False
# 118       False         False
# 119       False         False
# 120       False         False
# 165       False         False
# 223       False         False
# 363       False         False
# 390       False         False
# 391       False          True
# 392       False         False
# 481       False         False
# 515       False         False
# 559       False         False
# 610       False         False
# 641       False         False
# 690       False         False
# 691       False         False
# 692       False         False
# 693        True         False
# 694        True         False
# 695        True         False
# 696        True         False
# 697        True         False
# 698        True         False
# 815       False         False
# 816       False          True
# 817       False         False
# 895       False         False
# 896       False         False
# 897        True         False
# 898        True         False
# 950       False         False
# 980       False         False
# 1046      False         False
# 1078      False         False

# %%
passeddf.to_csv("%s/passed-%s.csv"%(OUTPUT_DIRECTORY,EXPERIMENT))

# %%
passed_counts = passeddf.loc[passeddf['passed']==True].groupby('idx').apply(len)

# %%
for idx, group in passeddf.groupby('idx'):
    passed_g = group.loc[group['passed']==True,'mcountsPF']
    thresh_val = passed_g.values[-1]
    over_thresh = len(group.loc[group['mcountsPF']>=thresh_val])
    print idx, thresh_val, len(group.loc[group['passed']==True,'mcountsPF']), over_thresh
# Out:
# 1 21979 1 1
# 180-10 878 2 2
# 180-12 74 3 3
# 2 61172 1 1
# 20 189720 1 1
# 21 13552 1 1
# 22 166365 1 1
# 23 15262 1 1
# 24 21939 1 1
# 25 42568 1 1
# 26 21539 1 1
# 27 24880 1 1
# 28 12084 3 3
# 29 68425 1 1
# 3 9876 2 2
# 4 28058 1 1
# 5 103126 1 1
# 6 23803 1 1
# 7 28025 1 1

# %% [markdown]
# ## GRAPHING

# %%
itypes = {
    (True,False,False):'passed', #passed
    (False,True,False):'qtag mismatch', #qtag error
    (False,False,True):'barcode oneoff', #barcode error
    (False,False,False):'other error' #not one-off
}

for itype in itypes:
    keys = ['passed','qtag_error','barcode_error']
    ca = [(merged[k]==v) for k,v in zip(keys,itype)]
    cond = ca[0]&ca[1]&ca[2]
    merged.loc[(cond),'itype'] = itypes[itype]
    
ctypes = {
    'passed':'#11BF08',
    'barcode oneoff': '#DE092B',
    'qtag mismatch':'#EBA709',
    'other error':'#2A52D5'
}
itype_order = [
    'passed',
    'other error',
    'barcode oneoff',
    'qtag mismatch'
]

# %%
# plots scatter
plottype = 'bar'
mcounts=MCOUNTS
counter = 0
for idx, group in merged.groupby('idx'):
#     if idx[:2]=='NH':
    if True:
        gslice = group.sort_values(by=mcounts,ascending=False)
        gslice = gslice.loc[gslice[mcounts]>1]
        counts = gslice[mcounts].values
        itypes = gslice.itype.values
        it_present= np.unique(itypes)
        
        f, ax = plt.subplots(1)
        for itype in itype_order:
            if itype in it_present:
                x = np.where(itypes==itype)[0]
                y = counts[x]
                label = "%s: %d"%(itype,len(x))
                color = ctypes[itype]
                alpha = 0.5 if itype in ['passed','other error'] else 1
                edgecolor=color
                lw = 1.5
                s = 250 if itype in ['barcode oneoff','qtag mismatch'] else 8
                marker = "|" if itype in ['barcode oneoff','qtag mismatch'] else "o"
                    
                if plottype == 'scatter':
                    ax.scatter(x+1, y, color=color, edgecolors=edgecolor,
                            alpha=alpha, label=label, 
                            marker=marker, lw=lw, s=s)
                    
                else:s
                    ax.bar(x, y, color=color, alpha=alpha, 
                           label=label, lw=0, width=1 )
        
        thresh_values = all_threshold_logs[idx]
        thresh_line_fmts = [1, 0.5]
        for tline in range(1,len(thresh_values)):
            thresh_line = thresh_values[tline] - 1
#             thresh_line =np.max(np.where(itypes=='passed')[0])+1
            alpha = thresh_line_fmts[len(thresh_values)-tline-1]
            ax.plot([thresh_line,thresh_line],[1,max(counts)], 
                    color = 'black', alpha = 1, ls = '--',
                    label='%d QB > threshold iter %d'%(thresh_line, tline+1))
        ax.set_yscale('log')
        ax.set_xlim(0)
        ax.legend()
        ax.set_title(idx)
        f.savefig('../output/%s_%s.png'%(EXPERIMENT,idx))
#         break
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-126-48c38779d3bd> in <module>()
#      39             thresh_line = thresh_values[tline] - 1
#      40 #             thresh_line =np.max(np.where(itypes=='passed')[0])+1
# ---> 41             alpha = thresh_line_fmts[len(thresh_values)-tline-1]
#      42             ax.plot([thresh_line,thresh_line],[1,max(counts)],
#      43                     color = 'black', alpha = 1, ls = '--',
#
# IndexError: list index out of range

# %%
merged.head()

# %%
# plots scatter
plottype = 'bar'
mcounts=MCOUNTS
counter = 0
for idx, group in merged.groupby('idx'):
#     if idx[:2]=='NH':
    if idx=='NH125':
        gslice = group.loc[group['itype'].isin(['passed','other error'])].sort_values(by=mcounts,ascending=False)
        gslice = gslice.loc[gslice[mcounts]>1]
        counts = gslice[mcounts].values
#         counts = range(len(gslice))
        
        itypes = gslice.itype.values
        it_present= np.unique(itypes)
        
        f, ax = plt.subplots(1)
        for itype in itype_order:
            if itype in it_present:
                x = np.where(itypes==itype)[0]
                y = counts[x]
                label = "%s: %d"%(itype,len(x))
                color = ctypes[itype]
                alpha = 0.5 if itype in ['passed','other error'] else 1
                edgecolor=color
                lw = 1.5
                s = 250 if itype in ['barcode oneoff','qtag mismatch'] else 8
                marker = "|" if itype in ['barcode oneoff','qtag mismatch'] else "-o"
                    
                if plottype == 'scatter':
                    ax.scatter(x+1, y, color=color, edgecolors=edgecolor,
                            alpha=alpha, label=label, 
                            marker=marker, lw=lw, s=s)
                    
                else:
                    ax.bar(x, y, color=color, alpha=alpha, 
                           label=label, lw=0, width=1 )
        
        thresh_values = all_threshold_logs[idx][:-1]
        thresh_line_fmts = [1, 0.5]
#         for tline in range(len(thresh_values)):
#             thresh_line = thresh_values[tline] - 1
# #             thresh_line =np.max(np.where(itypes=='passed')[0])+1
#             alpha = thresh_line_fmts[len(thresh_values)-tline-1]
#             ax.plot([thresh_line,thresh_line],[1,max(counts)], 
#                     color = 'black', alpha = 1, ls = '--',
#                     label='%d QB > threshold iter %d'%(thresh_line, tline+1))
        ax.set_yscale('log')
        ax.set_xlim(0)
        ax.legend()
        ax.set_title(idx)
#         break

# %%
all_threshold_logs

# %%
# plots scatter
plottype = 'bar'
mcounts=MCOUNTS
counter = 0
for idx, group in merged.groupby('idx'):
#     if idx[:2]=='NH':
    if True:
        gslice = group.sort_values(by=mcounts,ascending=False)
        gslice = gslice.loc[gslice[mcounts]>1]
        counts = gslice[mcounts].values
        itypes = gslice.itype.values
        it_present= np.unique(itypes)
        
        f, ax = plt.subplots(1)
        for itype in itype_order:
            if itype in it_present:
                x = np.where(itypes==itype)[0]
                y = counts[x]
                label = "%s: %d"%(itype,len(x))
                color = ctypes[itype]
                alpha = 0.5 if itype in ['passed','other error'] else 1
                edgecolor=color
                lw = 1.5
                s = 250 if itype in ['barcode oneoff','qtag mismatch'] else 8
                marker, linestyle = ("|","None") if itype in ['barcode oneoff','qtag mismatch'] else ("o","-")
#                 linesty
                    
                if plottype == 'scatter':
                    ax.scatter(x+1, y ,color=color, edgecolors=edgecolor, 
                            alpha=alpha, label=label, 
                            marker=marker, lw=lw, s=s)
                    if itype in ['barcode oneoff', 'qtag mismatch']:
                        ax.plot(x+1, y, color = color, alpha=alpha)
                    
                else:
                    ax.bar(x, y, color=color, alpha=alpha, 
                           label=label, lw=0, width=1 )
        
        thresh_values = all_threshold_logs[idx][1:]
        thresh_line_fmts = [1, 0.5]
        for tline in range(len(thresh_values)):
            
            thresh_line = thresh_values[tline] - 1
    #             thresh_line =np.max(np.where(itypes=='passed')[0])+1

            if thresh_line != thresh_values[tline-1]:
                alpha = thresh_line_fmts[len(thresh_values)-tline-1]
                ax.plot([thresh_line,thresh_line],[1,max(counts)], 
                        color = 'black', alpha = 1, ls = '--',
                        label='%d QB > threshold iter %d'%(thresh_line, tline+1))
        ax.set_yscale('log')
        ax.set_xlim(0)
        ax.legend()
        ax.set_title(idx)
#         break

# %%
all_threshold_logs

# %% [raw]
# #####  Color Palette by Paletton.com
# #####  Palette URL: http://paletton.com/#uid=c3P112O5x0kuKtzjHyVsYK-v+n-Cvj1
#
# 1.  BLUE    other error
# 2.  GREEN   passed
# 3.  RED     barcode oneoff
# 4.  YELLOW  qtag mismatch
#
# *** Primary color:
#
#    shade 0 = #18379F = rgb( 24, 55,159) = rgba( 24, 55,159,1) = rgb0(0.094,0.216,0.624)
#    shade 1 = #5269B4 = rgb( 82,105,180) = rgba( 82,105,180,1) = rgb0(0.322,0.412,0.706)
#    >>>>shade 2 = #2A52D5 = rgb( 42, 82,213) = rgba( 42, 82,213,1) = rgb0(0.165,0.322,0.835)<<<<
#    shade 3 = #0F297F = rgb( 15, 41,127) = rgba( 15, 41,127,1) = rgb0(0.059,0.161,0.498)
#    shade 4 = #091F67 = rgb(  9, 31,103) = rgba(  9, 31,103,1) = rgb0(0.035,0.122,0.404)
#
# *** Secondary color (1):
#
#    shade 0 = #11BF08 = rgb( 17,191,  8) = rgba( 17,191,  8,1) = rgb0(0.067,0.749,0.031)
#    shade 1 = #58D351 = rgb( 88,211, 81) = rgba( 88,211, 81,1) = rgb0(0.345,0.827,0.318)
#    shade 2 = #20E616 = rgb( 32,230, 22) = rgba( 32,230, 22,1) = rgb0(0.125,0.902,0.086)
#    shade 3 = #089800 = rgb(  8,152,  0) = rgba(  8,152,  0,1) = rgb0(0.031,0.596,0)
#    shade 4 = #067B00 = rgb(  6,123,  0) = rgba(  6,123,  0,1) = rgb0(0.024,0.482,0)
#
# *** Secondary color (2):
#
#    shade 0 = #DE092B = rgb(222,  9, 43) = rgba(222,  9, 43,1) = rgb0(0.871,0.035,0.169)
#    shade 1 = #F25D75 = rgb(242, 93,117) = rgba(242, 93,117,1) = rgb0(0.949,0.365,0.459)
#    shade 2 = #F8183B = rgb(248, 24, 59) = rgba(248, 24, 59,1) = rgb0(0.973,0.094,0.231)
#    shade 3 = #B1001C = rgb(177,  0, 28) = rgba(177,  0, 28,1) = rgb0(0.694,0,0.11)
#    shade 4 = #8F0017 = rgb(143,  0, 23) = rgba(143,  0, 23,1) = rgb0(0.561,0,0.09)
#
# *** Complement color:
#
#    shade 0 = #EBA709 = rgb(235,167,  9) = rgba(235,167,  9,1) = rgb0(0.922,0.655,0.035)
#    shade 1 = #FFCF62 = rgb(255,207, 98) = rgba(255,207, 98,1) = rgb0(1,0.812,0.384)
#    shade 2 = #FFB918 = rgb(255,185, 24) = rgba(255,185, 24,1) = rgb0(1,0.725,0.094)
#    shade 3 = #BC8300 = rgb(188,131,  0) = rgba(188,131,  0,1) = rgb0(0.737,0.514,0)
#    shade 4 = #986900 = rgb(152,105,  0) = rgba(152,105,  0,1) = rgb0(0.596,0.412,0)
#
#
# #####  Generated by Paletton.com (c) 2002-2014
